# %% [markdown]
# <img src = "https://d.newsweek.com/en/full/1620346/lewis-hamilton-valtteri-bottas-formula-one.webp?w=737&f=79a7af32e88f5cce1c63f6825e45c5c8"
# style="width: 1500px; height: 600px;">

# %% [markdown]
# # Formula 1 - Case Study
#
# # Author: Yi-Le Hung
#
# ## Formula One (more commonly known as Formula 1 or F1) is the highest class of international racing for open-wheel single-seater formula racing cars sanctioned by the Fédération Internationale de l'Automobile (FIA).
#
# ## The dataset consists of all information on the Formula 1 races, drivers, constructors, qualifying, circuits, lap times, pit stops, championships from 1950 till the latest 2023 season.

# %% [markdown]
# ## ER Diagram
# ![ER.pgerd.png](attachment:ER.pgerd.png)

# %%
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# %load_ext sql

# %%
#  Set your DATABASE_URL environment variable here
# %sql

# %% [markdown]
# ## 1. Identify the country which has produced the most F1 drivers.

# %%
# %%sql
# select nationality, count(1) as no_drivers
# from drivers
# group by 1
# order by 2 desc
# limit 10; -- Avoid for long output
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 42 rows affected.
# [('British', 165),
#  ('American', 158),
#  ('Italian', 99),
#  ('French', 73),
#  ('German', 50),
#  ('Brazilian', 32),
#  ('Argentine', 24),
#  ('South African', 23),
#  ('Swiss', 23),
#  ('Belgian', 23),
#  ('Japanese', 20),
#  ('Australian', 18),
#  ('Dutch', 18),
#  ('Spanish', 15),
#  ('Austrian', 15),
#  ('Canadian', 14),
#  ('Swedish', 10),
#  ('New Zealander', 9),
#  ('Finnish', 9),
#  ('Mexican', 6),
#  ('Irish', 5),
#  ('Danish', 5),
#  ('Rhodesian', 4),
#  ('Uruguayan', 4),
#  ('Russian', 4),
#  ('Monegasque', 4),
#  ('Portuguese', 4),
#  ('Venezuelan', 3),
#  ('East German', 3),
#  ('Colombian', 3),
#  ('Thai', 2),
#  ('Indian', 2),
#  ('Indonesian', 1),
#  ('Liechtensteiner', 1),
#  ('Chinese', 1),
#  ('Polish', 1),
#  ('Chilean', 1),
#  ('Czech', 1),
#  ('Hungarian', 1),
#  ('Malaysian', 1),
#  ('Argentine-Italian', 1),
#  ('American-Italian', 1)]

# %% [markdown]
# ## 2. Which country has produced the most no of F1 circuits

# %%
# %%sql
# select country, count(1) as no_circuits
# from circuits
# group by 1
# order by 2 desc
# limit 1;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 1 rows affected.
# [('USA', 11)]

# %% [markdown]
# ## 3. Which countries have produced exactly 5 constructors?

# %%
# %%sql
# select nationality, count(1) as no_constructors
# from constructors
# group by 1
# having count(1) = 5
# order by 2 desc;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 2 rows affected.
# [('Swiss', 5), ('Japanese', 5)]

# %% [markdown]
# ## 4. List down the no of races that have taken place each year

# %%
# %%sql
# select year, count(1) as no_races
# from races
# group by 1
# order by 2 desc
# limit 5; -- Avoid for long output
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 5 rows affected.
# [(2023, 23), (2022, 22), (2021, 22), (2016, 21), (2018, 21)]

# %% [markdown]
# ## 5. Who is the youngest and oldest F1 driver?

# %%
# %%sql
# with rk as  -- First temp_table is used to rank drivers by age from oldest to youngest.
# 	(select *,
# 	 dense_rank() over(order by age desc) as rk
#      from(
# 	 	select *, (to_char(current_date, 'yyyy')::int - to_char(dob, 'yyyy')::int) as age
# 	 	from drivers
# 		 ) x -- Subquery to find out the age for every driver
# 		),
# 	min_max as -- Second temp_table is used to find out the oldest and youngest driver.
# 	(
# 	select min(rk) as min, max(rk)
# 	from rk
# 	)
# select rk.forename||' '||rk.surname as Driver,
# case when rk = ma.max then 'Youngest_driver'
# 	  when rk = ma.min then 'Oldest_driver' end as age_flag
# from rk
# cross join min_max ma
# where rk = ma.max or rk = ma.min;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 2 rows affected.
# [('Philippe Étancelin', 'Oldest_driver'), ('Oscar Piastri', 'Youngest_driver')]

# %% [markdown]
# ## 6. List down the no of races that have taken place each year and mentioned which was the first and the last race of each season.

# %%
# %%sql
# select distinct year,
# first_value(name) over(partition by year order by date) as firstrace,
# last_value(name) over(partition by year order by date
# 					   range between unbounded preceding and unbounded following) as lastrace,
# count(*) over(partition by year) as no_races_of_year
# from races
# order by 4 desc
# limit 10; -- Avoid for long output
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 74 rows affected.
# [(2023, 'Bahrain Grand Prix', 'Abu Dhabi Grand Prix', 23),
#  (2022, 'Bahrain Grand Prix', 'Abu Dhabi Grand Prix', 22),
#  (2021, 'Bahrain Grand Prix', 'Abu Dhabi Grand Prix', 22),
#  (2016, 'Australian Grand Prix', 'Abu Dhabi Grand Prix', 21),
#  (2018, 'Australian Grand Prix', 'Abu Dhabi Grand Prix', 21),
#  (2019, 'Australian Grand Prix', 'Abu Dhabi Grand Prix', 21),
#  (2017, 'Australian Grand Prix', 'Abu Dhabi Grand Prix', 20),
#  (2012, 'Australian Grand Prix', 'Brazilian Grand Prix', 20),
#  (2010, 'Bahrain Grand Prix', 'Abu Dhabi Grand Prix', 19),
#  (2005, 'Australian Grand Prix', 'Chinese Grand Prix', 19),
#  (2011, 'Australian Grand Prix', 'Brazilian Grand Prix', 19),
#  (2013, 'Australian Grand Prix', 'Brazilian Grand Prix', 19),
#  (2015, 'Australian Grand Prix', 'Abu Dhabi Grand Prix', 19),
#  (2014, 'Australian Grand Prix', 'Abu Dhabi Grand Prix', 19),
#  (2008, 'Australian Grand Prix', 'Brazilian Grand Prix', 18),
#  (2006, 'Bahrain Grand Prix', 'Brazilian Grand Prix', 18),
#  (2004, 'Australian Grand Prix', 'Brazilian Grand Prix', 18),
#  (2020, 'Austrian Grand Prix', 'Abu Dhabi Grand Prix', 17),
#  (2007, 'Australian Grand Prix', 'Brazilian Grand Prix', 17),
#  (2002, 'Australian Grand Prix', 'Japanese Grand Prix', 17),
#  (1997, 'Australian Grand Prix', 'European Grand Prix', 17),
#  (1995, 'Brazilian Grand Prix', 'Australian Grand Prix', 17),
#  (2001, 'Australian Grand Prix', 'Japanese Grand Prix', 17),
#  (1977, 'Argentine Grand Prix', 'Japanese Grand Prix', 17),
#  (2000, 'Australian Grand Prix', 'Malaysian Grand Prix', 17),
#  (2009, 'Australian Grand Prix', 'Abu Dhabi Grand Prix', 17),
#  (1985, 'Brazilian Grand Prix', 'Australian Grand Prix', 16),
#  (1986, 'Brazilian Grand Prix', 'Australian Grand Prix', 16),
#  (1993, 'South African Grand Prix', 'Australian Grand Prix', 16),
#  (1992, 'South African Grand Prix', 'Australian Grand Prix', 16),
#  (1978, 'Argentine Grand Prix', 'Canadian Grand Prix', 16),
#  (1976, 'Brazilian Grand Prix', 'Japanese Grand Prix', 16),
#  (1996, 'Australian Grand Prix', 'Japanese Grand Prix', 16),
#  (1988, 'Brazilian Grand Prix', 'Australian Grand Prix', 16),
#  (1984, 'Brazilian Grand Prix', 'Portuguese Grand Prix', 16),
#  (1994, 'Brazilian Grand Prix', 'Australian Grand Prix', 16),
#  (1982, 'South African Grand Prix', 'Caesars Palace Grand Prix', 16),
#  (2003, 'Australian Grand Prix', 'Japanese Grand Prix', 16),
#  (1998, 'Australian Grand Prix', 'Japanese Grand Prix', 16),
#  (1987, 'Brazilian Grand Prix', 'Australian Grand Prix', 16),
#  (1990, 'United States Grand Prix', 'Australian Grand Prix', 16),
#  (1999, 'Australian Grand Prix', 'Japanese Grand Prix', 16),
#  (1989, 'Brazilian Grand Prix', 'Australian Grand Prix', 16),
#  (1991, 'United States Grand Prix', 'Australian Grand Prix', 16),
#  (1979, 'Argentine Grand Prix', 'United States Grand Prix', 15),
#  (1981, 'United States Grand Prix West', 'Caesars Palace Grand Prix', 15),
#  (1974, 'Argentine Grand Prix', 'United States Grand Prix', 15),
#  (1973, 'Argentine Grand Prix', 'United States Grand Prix', 15),
#  (1983, 'Brazilian Grand Prix', 'South African Grand Prix', 15),
#  (1975, 'Argentine Grand Prix', 'United States Grand Prix', 14),
#  (1980, 'Argentine Grand Prix', 'United States Grand Prix', 14),
#  (1970, 'South African Grand Prix', 'Mexican Grand Prix', 13),
#  (1972, 'Argentine Grand Prix', 'United States Grand Prix', 12),
#  (1968, 'South African Grand Prix', 'Mexican Grand Prix', 12),
#  (1971, 'South African Grand Prix', 'United States Grand Prix', 11),
#  (1967, 'South African Grand Prix', 'Mexican Grand Prix', 11),
#  (1958, 'Argentine Grand Prix', 'Moroccan Grand Prix', 11),
#  (1969, 'South African Grand Prix', 'Mexican Grand Prix', 11),
#  (1960, 'Argentine Grand Prix', 'United States Grand Prix', 10),
#  (1964, 'Monaco Grand Prix', 'Mexican Grand Prix', 10),
#  (1965, 'South African Grand Prix', 'Mexican Grand Prix', 10),
#  (1963, 'Monaco Grand Prix', 'South African Grand Prix', 10),
#  (1966, 'Monaco Grand Prix', 'Mexican Grand Prix', 9),
#  (1953, 'Argentine Grand Prix', 'Italian Grand Prix', 9),
#  (1959, 'Monaco Grand Prix', 'United States Grand Prix', 9),
#  (1962, 'Dutch Grand Prix', 'South African Grand Prix', 9),
#  (1954, 'Argentine Grand Prix', 'Spanish Grand Prix', 9),
#  (1956, 'Argentine Grand Prix', 'Italian Grand Prix', 8),
#  (1951, 'Swiss Grand Prix', 'Spanish Grand Prix', 8),
#  (1952, 'Swiss Grand Prix', 'Italian Grand Prix', 8),
#  (1961, 'Monaco Grand Prix', 'United States Grand Prix', 8),
#  (1957, 'Argentine Grand Prix', 'Italian Grand Prix', 8),
#  (1955, 'Argentine Grand Prix', 'Italian Grand Prix', 7),
#  (1950, 'British Grand Prix', 'Italian Grand Prix', 7)]

# %% [markdown]
# ## 7. Which circuit has hosted the most no of races. Display the circuit name, no of races, city and country.

# %%
# %%sql
# select circuit_name, no_races, city, country
# from
# 	(
# 	select c.name as circuit_name, count(1) as no_races, max(c.location) as city, max(c.country) as country,
# 	dense_rank() over(order by count(1) desc) as rk
# 	from races r
# 	join circuits c on r.circuitid = c.circuitid
# 	group by 1
# 	order by 2 desc
# 	)x
# where rk = 1;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 1 rows affected.
# [('Autodromo Nazionale di Monza', 73, 'Monza', 'Italy')]

# %% [markdown]
# ## 8. Display the following for 2022 season:
# ## Year, Race_no, circuit name, driver name, driver race position, driver race points, flag to indicate if winner
# ## constructor name, constructor position, constructor points, , flag to indicate if constructor is winner,
# ## race status of each driver, flag to indicate fastest lap for which driver, total no of pit stops by each driver

# %%
# %%sql
# select d.driverid, r.year as year, r.raceid as race_no, r.name as circuit_name,
# d.forename||' '||d.surname as driver_name, ds.position as position, ds.points as points
# ,case when ds.position = 1 then 'Winner' End as Driver_flag
# ,c.name as team_name, cs.position as team_position, cs.points as team_points
# ,case when cs.position = 1 then 'Team Winner' End as Team_flag, s.status
# ,case when fas.fastestlap = re.fastestlaptime then 'Fastest Lap' end as lap_flag, no_pit_stop
# from races r
# join driver_standings ds on r.raceid = ds.raceid
# join drivers d on ds.driverid = d.driverid
# join constructor_standings cs on cs.raceid = r.raceid
# join results re on d.driverid = re.driverid and re.raceid = r.raceid and cs.constructorid = re.constructorid
# join constructors c on cs.constructorid = c.constructorid
# join status s on re.statusid = s.statusid
# left join (
# 			select raceid, min(fastestlaptime) as fastestlap
# 			from results
# 			group by 1) fas on fas.raceid = r.raceid
# left join (
# 			select raceid, driverid, count(1) no_pit_stop
# 			from pit_stops
# 			group by 1,2) pit on pit.driverid = d.driverid and pit.raceid = r.raceid
# where r.year = 2022
# order by r.raceid, race_no, position
# limit 10; -- Avoid for long output
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 440 rows affected.
# [(844, 2022, 1074, 'Bahrain Grand Prix', 'Charles Leclerc', 1, Decimal('26'), 'Winner', 'Ferrari', 1, Decimal('44'), 'Team Winner', 'Finished', 'Fastest Lap', 3),
#  (832, 2022, 1074, 'Bahrain Grand Prix', 'Carlos Sainz', 2, Decimal('18'), None, 'Ferrari', 1, Decimal('44'), 'Team Winner', 'Finished', None, 3),
#  (1, 2022, 1074, 'Bahrain Grand Prix', 'Lewis Hamilton', 3, Decimal('15'), None, 'Mercedes', 2, Decimal('27'), None, 'Finished', None, 3),
#  (847, 2022, 1074, 'Bahrain Grand Prix', 'George Russell', 4, Decimal('12'), None, 'Mercedes', 2, Decimal('27'), None, 'Finished', None, 3),
#  (825, 2022, 1074, 'Bahrain Grand Prix', 'Kevin Magnussen', 5, Decimal('10'), None, 'Haas F1 Team', 3, Decimal('10'), None, 'Finished', None, 3),
#  (822, 2022, 1074, 'Bahrain Grand Prix', 'Valtteri Bottas', 6, Decimal('8'), None, 'Alfa Romeo', 4, Decimal('9'), None, 'Finished', None, 3),
#  (839, 2022, 1074, 'Bahrain Grand Prix', 'Esteban Ocon', 7, Decimal('6'), None, 'Alpine F1 Team', 5, Decimal('8'), None, 'Finished', None, 3),
#  (852, 2022, 1074, 'Bahrain Grand Prix', 'Yuki Tsunoda', 8, Decimal('4'), None, 'AlphaTauri', 6, Decimal('4'), None, 'Finished', None, 3),
#  (4, 2022, 1074, 'Bahrain Grand Prix', 'Fernando Alonso', 9, Decimal('2'), None, 'Alpine F1 Team', 5, Decimal('8'), None, 'Finished', None, 3),
#  (855, 2022, 1074, 'Bahrain Grand Prix', 'Guanyu Zhou', 10, Decimal('1'), None, 'Alfa Romeo', 4, Decimal('9'), None, 'Finished', None, 3),
#  (854, 2022, 1074, 'Bahrain Grand Prix', 'Mick Schumacher', 11, Decimal('0'), None, 'Haas F1 Team', 3, Decimal('10'), None, 'Finished', None, 2),
#  (840, 2022, 1074, 'Bahrain Grand Prix', 'Lance Stroll', 12, Decimal('0'), None, 'Aston Martin', 7, Decimal('0'), None, 'Finished', None, 3),
#  (848, 2022, 1074, 'Bahrain Grand Prix', 'Alexander Albon', 13, Decimal('0'), None, 'Williams', 8, Decimal('0'), None, 'Finished', None, 3),
#  (817, 2022, 1074, 'Bahrain Grand Prix', 'Daniel Ricciardo', 14, Decimal('0'), None, 'McLaren', 9, Decimal('0'), None, 'Finished', None, 3),
#  (846, 2022, 1074, 'Bahrain Grand Prix', 'Lando Norris', 15, Decimal('0'), None, 'McLaren', 9, Decimal('0'), None, 'Finished', None, 3),
#  (849, 2022, 1074, 'Bahrain Grand Prix', 'Nicholas Latifi', 16, Decimal('0'), None, 'Williams', 8, Decimal('0'), None, 'Finished', None, 3),
#  (807, 2022, 1074, 'Bahrain Grand Prix', 'Nico Hülkenberg', 17, Decimal('0'), None, 'Aston Martin', 7, Decimal('0'), None, 'Finished', None, 3),
#  (815, 2022, 1074, 'Bahrain Grand Prix', 'Sergio Pérez', 18, Decimal('0'), None, 'Red Bull', 10, Decimal('0'), None, 'Fuel pressure', None, 3),
#  (830, 2022, 1074, 'Bahrain Grand Prix', 'Max Verstappen', 19, Decimal('0'), None, 'Red Bull', 10, Decimal('0'), None, 'Fuel pressure', None, 3),
#  (842, 2022, 1074, 'Bahrain Grand Prix', 'Pierre Gasly', 20, Decimal('0'), None, 'AlphaTauri', 6, Decimal('4'), None, 'Power Unit', None, 2),
#  (844, 2022, 1075, 'Saudi Arabian Grand Prix', 'Charles Leclerc', 1, Decimal('45'), 'Winner', 'Ferrari', 1, Decimal('78'), 'Team Winner', 'Finished', 'Fastest Lap', 1),
#  (832, 2022, 1075, 'Saudi Arabian Grand Prix', 'Carlos Sainz', 2, Decimal('33'), None, 'Ferrari', 1, Decimal('78'), 'Team Winner', 'Finished', None, 1),
#  (830, 2022, 1075, 'Saudi Arabian Grand Prix', 'Max Verstappen', 3, Decimal('25'), None, 'Red Bull', 3, Decimal('37'), None, 'Finished', None, 1),
#  (847, 2022, 1075, 'Saudi Arabian Grand Prix', 'George Russell', 4, Decimal('22'), None, 'Mercedes', 2, Decimal('38'), None, 'Finished', None, 1),
#  (1, 2022, 1075, 'Saudi Arabian Grand Prix', 'Lewis Hamilton', 5, Decimal('16'), None, 'Mercedes', 2, Decimal('38'), None, 'Finished', None, 1),
#  (839, 2022, 1075, 'Saudi Arabian Grand Prix', 'Esteban Ocon', 6, Decimal('14'), None, 'Alpine F1 Team', 4, Decimal('16'), None, 'Finished', None, 1),
#  (815, 2022, 1075, 'Saudi Arabian Grand Prix', 'Sergio Pérez', 7, Decimal('12'), None, 'Red Bull', 3, Decimal('37'), None, 'Finished', None, 1),
#  (825, 2022, 1075, 'Saudi Arabian Grand Prix', 'Kevin Magnussen', 8, Decimal('12'), None, 'Haas F1 Team', 5, Decimal('12'), None, 'Finished', None, 1),
#  (822, 2022, 1075, 'Saudi Arabian Grand Prix', 'Valtteri Bottas', 9, Decimal('8'), None, 'Alfa Romeo', 6, Decimal('9'), None, 'Cooling system', None, 2),
#  (846, 2022, 1075, 'Saudi Arabian Grand Prix', 'Lando Norris', 10, Decimal('6'), None, 'McLaren', 8, Decimal('6'), None, 'Finished', None, 1),
#  (852, 2022, 1075, 'Saudi Arabian Grand Prix', 'Yuki Tsunoda', 11, Decimal('4'), None, 'AlphaTauri', 7, Decimal('8'), None, 'Power Unit', None, None),
#  (842, 2022, 1075, 'Saudi Arabian Grand Prix', 'Pierre Gasly', 12, Decimal('4'), None, 'AlphaTauri', 7, Decimal('8'), None, 'Finished', None, 1),
#  (4, 2022, 1075, 'Saudi Arabian Grand Prix', 'Fernando Alonso', 13, Decimal('2'), None, 'Alpine F1 Team', 4, Decimal('16'), None, 'Water pump', None, 1),
#  (855, 2022, 1075, 'Saudi Arabian Grand Prix', 'Guanyu Zhou', 14, Decimal('1'), None, 'Alfa Romeo', 6, Decimal('9'), None, 'Finished', None, 2),
#  (854, 2022, 1075, 'Saudi Arabian Grand Prix', 'Mick Schumacher', 15, Decimal('0'), None, 'Haas F1 Team', 5, Decimal('12'), None, 'Withdrew', None, None),
#  (840, 2022, 1075, 'Saudi Arabian Grand Prix', 'Lance Stroll', 16, Decimal('0'), None, 'Aston Martin', 9, Decimal('0'), None, '+1 Lap', None, 1),
#  (807, 2022, 1075, 'Saudi Arabian Grand Prix', 'Nico Hülkenberg', 17, Decimal('0'), None, 'Aston Martin', 9, Decimal('0'), None, 'Finished', None, 1),
#  (848, 2022, 1075, 'Saudi Arabian Grand Prix', 'Alexander Albon', 18, Decimal('0'), None, 'Williams', 10, Decimal('0'), None, 'Collision damage', None, 1),
#  (817, 2022, 1075, 'Saudi Arabian Grand Prix', 'Daniel Ricciardo', 19, Decimal('0'), None, 'McLaren', 8, Decimal('6'), None, 'Gearbox', None, 1),
#  (849, 2022, 1075, 'Saudi Arabian Grand Prix', 'Nicholas Latifi', 20, Decimal('0'), None, 'Williams', 10, Decimal('0'), None, 'Accident', None, None),
#  (844, 2022, 1076, 'Australian Grand Prix', 'Charles Leclerc', 1, Decimal('71'), 'Winner', 'Ferrari', 1, Decimal('104'), 'Team Winner', 'Finished', 'Fastest Lap', 1),
#  (847, 2022, 1076, 'Australian Grand Prix', 'George Russell', 2, Decimal('37'), None, 'Mercedes', 2, Decimal('65'), None, 'Finished', None, 1),
#  (832, 2022, 1076, 'Australian Grand Prix', 'Carlos Sainz', 3, Decimal('33'), None, 'Ferrari', 1, Decimal('104'), 'Team Winner', 'Spun off', None, None),
#  (815, 2022, 1076, 'Australian Grand Prix', 'Sergio Pérez', 4, Decimal('30'), None, 'Red Bull', 3, Decimal('55'), None, 'Finished', None, 1),
#  (1, 2022, 1076, 'Australian Grand Prix', 'Lewis Hamilton', 5, Decimal('28'), None, 'Mercedes', 2, Decimal('65'), None, 'Finished', None, 1),
#  (830, 2022, 1076, 'Australian Grand Prix', 'Max Verstappen', 6, Decimal('25'), None, 'Red Bull', 3, Decimal('55'), None, 'Fuel leak', None, 1),
#  (839, 2022, 1076, 'Australian Grand Prix', 'Esteban Ocon', 7, Decimal('20'), None, 'Alpine F1 Team', 5, Decimal('22'), None, 'Finished', None, 1),
#  (846, 2022, 1076, 'Australian Grand Prix', 'Lando Norris', 8, Decimal('16'), None, 'McLaren', 4, Decimal('24'), None, 'Finished', None, 1),
#  (825, 2022, 1076, 'Australian Grand Prix', 'Kevin Magnussen', 9, Decimal('12'), None, 'Haas F1 Team', 7, Decimal('12'), None, '+1 Lap', None, 1),
#  (822, 2022, 1076, 'Australian Grand Prix', 'Valtteri Bottas', 10, Decimal('12'), None, 'Alfa Romeo', 6, Decimal('13'), None, 'Finished', None, 1),
#  (817, 2022, 1076, 'Australian Grand Prix', 'Daniel Ricciardo', 11, Decimal('8'), None, 'McLaren', 4, Decimal('24'), None, 'Finished', None, 1),
#  (842, 2022, 1076, 'Australian Grand Prix', 'Pierre Gasly', 12, Decimal('6'), None, 'AlphaTauri', 8, Decimal('10'), None, 'Finished', None, 1),
#  (852, 2022, 1076, 'Australian Grand Prix', 'Yuki Tsunoda', 13, Decimal('4'), None, 'AlphaTauri', 8, Decimal('10'), None, '+1 Lap', None, 1),
#  (4, 2022, 1076, 'Australian Grand Prix', 'Fernando Alonso', 14, Decimal('2'), None, 'Alpine F1 Team', 5, Decimal('22'), None, '+1 Lap', None, 2),
#  (855, 2022, 1076, 'Australian Grand Prix', 'Guanyu Zhou', 15, Decimal('1'), None, 'Alfa Romeo', 6, Decimal('13'), None, 'Finished', None, 1),
#  (848, 2022, 1076, 'Australian Grand Prix', 'Alexander Albon', 16, Decimal('1'), None, 'Williams', 9, Decimal('1'), None, 'Finished', None, 1),
#  (854, 2022, 1076, 'Australian Grand Prix', 'Mick Schumacher', 17, Decimal('0'), None, 'Haas F1 Team', 7, Decimal('12'), None, '+1 Lap', None, 1),
#  (840, 2022, 1076, 'Australian Grand Prix', 'Lance Stroll', 18, Decimal('0'), None, 'Aston Martin', 10, Decimal('0'), None, 'Finished', None, 3),
#  (849, 2022, 1076, 'Australian Grand Prix', 'Nicholas Latifi', 20, Decimal('0'), None, 'Williams', 9, Decimal('1'), None, '+1 Lap', None, 2),
#  (20, 2022, 1076, 'Australian Grand Prix', 'Sebastian Vettel', 21, Decimal('0'), None, 'Aston Martin', 10, Decimal('0'), None, 'Accident', None, None),
#  (844, 2022, 1077, 'Emilia Romagna Grand Prix', 'Charles Leclerc', 1, Decimal('86'), 'Winner', 'Ferrari', 1, Decimal('124'), 'Team Winner', 'Finished', None, 3),
#  (830, 2022, 1077, 'Emilia Romagna Grand Prix', 'Max Verstappen', 2, Decimal('59'), None, 'Red Bull', 2, Decimal('113'), None, 'Finished', 'Fastest Lap', 2),
#  (815, 2022, 1077, 'Emilia Romagna Grand Prix', 'Sergio Pérez', 3, Decimal('54'), None, 'Red Bull', 2, Decimal('113'), None, 'Finished', None, 2),
#  (847, 2022, 1077, 'Emilia Romagna Grand Prix', 'George Russell', 4, Decimal('49'), None, 'Mercedes', 3, Decimal('77'), None, 'Finished', None, 1),
#  (832, 2022, 1077, 'Emilia Romagna Grand Prix', 'Carlos Sainz', 5, Decimal('38'), None, 'Ferrari', 1, Decimal('124'), 'Team Winner', 'Collision', None, None),
#  (846, 2022, 1077, 'Emilia Romagna Grand Prix', 'Lando Norris', 6, Decimal('35'), None, 'McLaren', 4, Decimal('46'), None, 'Finished', None, 1),
#  (1, 2022, 1077, 'Emilia Romagna Grand Prix', 'Lewis Hamilton', 7, Decimal('28'), None, 'Mercedes', 3, Decimal('77'), None, '+1 Lap', None, 1),
#  (822, 2022, 1077, 'Emilia Romagna Grand Prix', 'Valtteri Bottas', 8, Decimal('24'), None, 'Alfa Romeo', 5, Decimal('25'), None, 'Finished', None, 1),
#  (839, 2022, 1077, 'Emilia Romagna Grand Prix', 'Esteban Ocon', 9, Decimal('20'), None, 'Alpine F1 Team', 6, Decimal('22'), None, '+1 Lap', None, 1),
#  (825, 2022, 1077, 'Emilia Romagna Grand Prix', 'Kevin Magnussen', 10, Decimal('15'), None, 'Haas F1 Team', 8, Decimal('15'), None, 'Finished', None, 1),
#  (817, 2022, 1077, 'Emilia Romagna Grand Prix', 'Daniel Ricciardo', 11, Decimal('11'), None, 'McLaren', 4, Decimal('46'), None, '+1 Lap', None, 3),
#  (852, 2022, 1077, 'Emilia Romagna Grand Prix', 'Yuki Tsunoda', 12, Decimal('10'), None, 'AlphaTauri', 7, Decimal('16'), None, 'Finished', None, 1),
#  (842, 2022, 1077, 'Emilia Romagna Grand Prix', 'Pierre Gasly', 13, Decimal('6'), None, 'AlphaTauri', 7, Decimal('16'), None, '+1 Lap', None, 1),
#  (20, 2022, 1077, 'Emilia Romagna Grand Prix', 'Sebastian Vettel', 14, Decimal('4'), None, 'Aston Martin', 9, Decimal('5'), None, 'Finished', None, 1),
#  (4, 2022, 1077, 'Emilia Romagna Grand Prix', 'Fernando Alonso', 15, Decimal('2'), None, 'Alpine F1 Team', 6, Decimal('22'), None, 'Collision damage', None, None),
#  (855, 2022, 1077, 'Emilia Romagna Grand Prix', 'Guanyu Zhou', 16, Decimal('1'), None, 'Alfa Romeo', 5, Decimal('25'), None, '+1 Lap', None, 1),
#  (848, 2022, 1077, 'Emilia Romagna Grand Prix', 'Alexander Albon', 17, Decimal('1'), None, 'Williams', 10, Decimal('1'), None, '+1 Lap', None, 1),
#  (840, 2022, 1077, 'Emilia Romagna Grand Prix', 'Lance Stroll', 18, Decimal('1'), None, 'Aston Martin', 9, Decimal('5'), None, '+1 Lap', None, 1),
#  (854, 2022, 1077, 'Emilia Romagna Grand Prix', 'Mick Schumacher', 19, Decimal('0'), None, 'Haas F1 Team', 8, Decimal('15'), None, '+1 Lap', None, 2),
#  (849, 2022, 1077, 'Emilia Romagna Grand Prix', 'Nicholas Latifi', 21, Decimal('0'), None, 'Williams', 10, Decimal('1'), None, '+1 Lap', None, 1),
#  (844, 2022, 1078, 'Miami Grand Prix', 'Charles Leclerc', 1, Decimal('104'), 'Winner', 'Ferrari', 1, Decimal('157'), 'Team Winner', 'Finished', None, 1),
#  (830, 2022, 1078, 'Miami Grand Prix', 'Max Verstappen', 2, Decimal('85'), None, 'Red Bull', 2, Decimal('151'), None, 'Finished', 'Fastest Lap', 1),
#  (815, 2022, 1078, 'Miami Grand Prix', 'Sergio Pérez', 3, Decimal('66'), None, 'Red Bull', 2, Decimal('151'), None, 'Finished', None, 2),
#  (847, 2022, 1078, 'Miami Grand Prix', 'George Russell', 4, Decimal('59'), None, 'Mercedes', 3, Decimal('95'), None, 'Finished', None, 1),
#  (832, 2022, 1078, 'Miami Grand Prix', 'Carlos Sainz', 5, Decimal('53'), None, 'Ferrari', 1, Decimal('157'), 'Team Winner', 'Finished', None, 1),
#  (1, 2022, 1078, 'Miami Grand Prix', 'Lewis Hamilton', 6, Decimal('36'), None, 'Mercedes', 3, Decimal('95'), None, 'Finished', None, 1),
#  (846, 2022, 1078, 'Miami Grand Prix', 'Lando Norris', 7, Decimal('35'), None, 'McLaren', 4, Decimal('46'), None, 'Collision', None, 1),
#  (822, 2022, 1078, 'Miami Grand Prix', 'Valtteri Bottas', 8, Decimal('30'), None, 'Alfa Romeo', 5, Decimal('31'), None, 'Finished', None, 1),
#  (839, 2022, 1078, 'Miami Grand Prix', 'Esteban Ocon', 9, Decimal('24'), None, 'Alpine F1 Team', 6, Decimal('26'), None, 'Finished', None, 1),
#  (825, 2022, 1078, 'Miami Grand Prix', 'Kevin Magnussen', 10, Decimal('15'), None, 'Haas F1 Team', 8, Decimal('15'), None, 'Front wing', None, 2),
#  (817, 2022, 1078, 'Miami Grand Prix', 'Daniel Ricciardo', 11, Decimal('11'), None, 'McLaren', 4, Decimal('46'), None, 'Finished', None, 2),
#  (852, 2022, 1078, 'Miami Grand Prix', 'Yuki Tsunoda', 12, Decimal('10'), None, 'AlphaTauri', 7, Decimal('16'), None, 'Finished', None, 2),
#  (842, 2022, 1078, 'Miami Grand Prix', 'Pierre Gasly', 13, Decimal('6'), None, 'AlphaTauri', 7, Decimal('16'), None, 'Suspension', None, 2),
#  (20, 2022, 1078, 'Miami Grand Prix', 'Sebastian Vettel', 14, Decimal('4'), None, 'Aston Martin', 9, Decimal('6'), None, 'Collision', None, 1),
#  (848, 2022, 1078, 'Miami Grand Prix', 'Alexander Albon', 15, Decimal('3'), None, 'Williams', 10, Decimal('3'), None, 'Finished', None, 1),
#  (4, 2022, 1078, 'Miami Grand Prix', 'Fernando Alonso', 16, Decimal('2'), None, 'Alpine F1 Team', 6, Decimal('26'), None, 'Finished', None, 1),
#  (840, 2022, 1078, 'Miami Grand Prix', 'Lance Stroll', 17, Decimal('2'), None, 'Aston Martin', 9, Decimal('6'), None, 'Finished', None, 1),
#  (855, 2022, 1078, 'Miami Grand Prix', 'Guanyu Zhou', 18, Decimal('1'), None, 'Alfa Romeo', 5, Decimal('31'), None, 'Water leak', None, None),
#  (854, 2022, 1078, 'Miami Grand Prix', 'Mick Schumacher', 19, Decimal('0'), None, 'Haas F1 Team', 8, Decimal('15'), None, 'Finished', None, 2),
#  (849, 2022, 1078, 'Miami Grand Prix', 'Nicholas Latifi', 21, Decimal('0'), None, 'Williams', 10, Decimal('3'), None, 'Finished', None, 1),
#  (830, 2022, 1079, 'Spanish Grand Prix', 'Max Verstappen', 1, Decimal('110'), 'Winner', 'Red Bull', 1, Decimal('195'), 'Team Winner', 'Finished', None, 3),
#  (844, 2022, 1079, 'Spanish Grand Prix', 'Charles Leclerc', 2, Decimal('104'), None, 'Ferrari', 2, Decimal('169'), None, 'Turbo', None, 1),
#  (815, 2022, 1079, 'Spanish Grand Prix', 'Sergio Pérez', 3, Decimal('85'), None, 'Red Bull', 1, Decimal('195'), 'Team Winner', 'Finished', 'Fastest Lap', 3),
#  (847, 2022, 1079, 'Spanish Grand Prix', 'George Russell', 4, Decimal('74'), None, 'Mercedes', 3, Decimal('120'), None, 'Finished', None, 3),
#  (832, 2022, 1079, 'Spanish Grand Prix', 'Carlos Sainz', 5, Decimal('65'), None, 'Ferrari', 2, Decimal('169'), None, 'Finished', None, 3),
#  (1, 2022, 1079, 'Spanish Grand Prix', 'Lewis Hamilton', 6, Decimal('46'), None, 'Mercedes', 3, Decimal('120'), None, 'Finished', None, 3),
#  (846, 2022, 1079, 'Spanish Grand Prix', 'Lando Norris', 7, Decimal('39'), None, 'McLaren', 4, Decimal('50'), None, 'Finished', None, 3),
#  (822, 2022, 1079, 'Spanish Grand Prix', 'Valtteri Bottas', 8, Decimal('38'), None, 'Alfa Romeo', 5, Decimal('39'), None, 'Finished', None, 2),
#  (839, 2022, 1079, 'Spanish Grand Prix', 'Esteban Ocon', 9, Decimal('30'), None, 'Alpine F1 Team', 6, Decimal('34'), None, 'Finished', None, 3),
#  (825, 2022, 1079, 'Spanish Grand Prix', 'Kevin Magnussen', 10, Decimal('15'), None, 'Haas F1 Team', 8, Decimal('15'), None, '+2 Laps', None, 2),
#  (852, 2022, 1079, 'Spanish Grand Prix', 'Yuki Tsunoda', 11, Decimal('11'), None, 'AlphaTauri', 7, Decimal('17'), None, '+1 Lap', None, 3),
#  (817, 2022, 1079, 'Spanish Grand Prix', 'Daniel Ricciardo', 12, Decimal('11'), None, 'McLaren', 4, Decimal('50'), None, '+1 Lap', None, 3),
#  (842, 2022, 1079, 'Spanish Grand Prix', 'Pierre Gasly', 13, Decimal('6'), None, 'AlphaTauri', 7, Decimal('17'), None, '+1 Lap', None, 3),
#  (20, 2022, 1079, 'Spanish Grand Prix', 'Sebastian Vettel', 14, Decimal('4'), None, 'Aston Martin', 9, Decimal('6'), None, '+1 Lap', None, 2),
#  (4, 2022, 1079, 'Spanish Grand Prix', 'Fernando Alonso', 15, Decimal('4'), None, 'Alpine F1 Team', 6, Decimal('34'), None, '+1 Lap', None, 3),
#  (848, 2022, 1079, 'Spanish Grand Prix', 'Alexander Albon', 16, Decimal('3'), None, 'Williams', 10, Decimal('3'), None, '+2 Laps', None, 4),
#  (840, 2022, 1079, 'Spanish Grand Prix', 'Lance Stroll', 17, Decimal('2'), None, 'Aston Martin', 9, Decimal('6'), None, '+1 Lap', None, 3),
#  (855, 2022, 1079, 'Spanish Grand Prix', 'Guanyu Zhou', 18, Decimal('1'), None, 'Alfa Romeo', 5, Decimal('39'), None, 'Power loss', None, 1),
#  (854, 2022, 1079, 'Spanish Grand Prix', 'Mick Schumacher', 19, Decimal('0'), None, 'Haas F1 Team', 8, Decimal('15'), None, '+1 Lap', None, 2),
#  (849, 2022, 1079, 'Spanish Grand Prix', 'Nicholas Latifi', 21, Decimal('0'), None, 'Williams', 10, Decimal('3'), None, '+2 Laps', None, 3),
#  (830, 2022, 1080, 'Monaco Grand Prix', 'Max Verstappen', 1, Decimal('125'), 'Winner', 'Red Bull', 1, Decimal('235'), 'Team Winner', 'Finished', None, 3),
#  (844, 2022, 1080, 'Monaco Grand Prix', 'Charles Leclerc', 2, Decimal('116'), None, 'Ferrari', 2, Decimal('199'), None, 'Finished', None, 3),
#  (815, 2022, 1080, 'Monaco Grand Prix', 'Sergio Pérez', 3, Decimal('110'), None, 'Red Bull', 1, Decimal('235'), 'Team Winner', 'Finished', None, 3),
#  (847, 2022, 1080, 'Monaco Grand Prix', 'George Russell', 4, Decimal('84'), None, 'Mercedes', 3, Decimal('134'), None, 'Finished', None, 2),
#  (832, 2022, 1080, 'Monaco Grand Prix', 'Carlos Sainz', 5, Decimal('83'), None, 'Ferrari', 2, Decimal('199'), None, 'Finished', None, 2),
#  (1, 2022, 1080, 'Monaco Grand Prix', 'Lewis Hamilton', 6, Decimal('50'), None, 'Mercedes', 3, Decimal('134'), None, 'Finished', None, 3),
#  (846, 2022, 1080, 'Monaco Grand Prix', 'Lando Norris', 7, Decimal('48'), None, 'McLaren', 4, Decimal('59'), None, 'Finished', 'Fastest Lap', 4),
#  (822, 2022, 1080, 'Monaco Grand Prix', 'Valtteri Bottas', 8, Decimal('40'), None, 'Alfa Romeo', 5, Decimal('41'), None, 'Finished', None, 2),
#  (839, 2022, 1080, 'Monaco Grand Prix', 'Esteban Ocon', 9, Decimal('30'), None, 'Alpine F1 Team', 6, Decimal('40'), None, 'Finished', None, 2),
#  (825, 2022, 1080, 'Monaco Grand Prix', 'Kevin Magnussen', 10, Decimal('15'), None, 'Haas F1 Team', 8, Decimal('15'), None, 'Water pressure', None, None),
#  (817, 2022, 1080, 'Monaco Grand Prix', 'Daniel Ricciardo', 11, Decimal('11'), None, 'McLaren', 4, Decimal('59'), None, 'Finished', None, 2),
#  (852, 2022, 1080, 'Monaco Grand Prix', 'Yuki Tsunoda', 12, Decimal('11'), None, 'AlphaTauri', 7, Decimal('17'), None, '+1 Lap', None, 4),
#  (4, 2022, 1080, 'Monaco Grand Prix', 'Fernando Alonso', 13, Decimal('10'), None, 'Alpine F1 Team', 6, Decimal('40'), None, 'Finished', None, 2),
#  (842, 2022, 1080, 'Monaco Grand Prix', 'Pierre Gasly', 14, Decimal('6'), None, 'AlphaTauri', 7, Decimal('17'), None, 'Finished', None, 3),
#  (20, 2022, 1080, 'Monaco Grand Prix', 'Sebastian Vettel', 15, Decimal('5'), None, 'Aston Martin', 9, Decimal('7'), None, 'Finished', None, 3),
#  (848, 2022, 1080, 'Monaco Grand Prix', 'Alexander Albon', 16, Decimal('3'), None, 'Williams', 10, Decimal('3'), None, 'Mechanical', None, 3),
#  (840, 2022, 1080, 'Monaco Grand Prix', 'Lance Stroll', 17, Decimal('2'), None, 'Aston Martin', 9, Decimal('7'), None, 'Finished', None, 4),
#  (855, 2022, 1080, 'Monaco Grand Prix', 'Guanyu Zhou', 18, Decimal('1'), None, 'Alfa Romeo', 5, Decimal('41'), None, '+1 Lap', None, 2),
#  (854, 2022, 1080, 'Monaco Grand Prix', 'Mick Schumacher', 19, Decimal('0'), None, 'Haas F1 Team', 8, Decimal('15'), None, 'Accident', None, 2),
#  (849, 2022, 1080, 'Monaco Grand Prix', 'Nicholas Latifi', 21, Decimal('0'), None, 'Williams', 10, Decimal('3'), None, '+1 Lap', None, 4),
#  (830, 2022, 1081, 'Azerbaijan Grand Prix', 'Max Verstappen', 1, Decimal('150'), 'Winner', 'Red Bull', 1, Decimal('279'), 'Team Winner', 'Finished', None, 2),
#  (815, 2022, 1081, 'Azerbaijan Grand Prix', 'Sergio Pérez', 2, Decimal('129'), None, 'Red Bull', 1, Decimal('279'), 'Team Winner', 'Finished', 'Fastest Lap', 2),
#  (844, 2022, 1081, 'Azerbaijan Grand Prix', 'Charles Leclerc', 3, Decimal('116'), None, 'Ferrari', 2, Decimal('199'), None, 'Power Unit', None, 1),
#  (847, 2022, 1081, 'Azerbaijan Grand Prix', 'George Russell', 4, Decimal('99'), None, 'Mercedes', 3, Decimal('161'), None, 'Finished', None, 2),
#  (832, 2022, 1081, 'Azerbaijan Grand Prix', 'Carlos Sainz', 5, Decimal('83'), None, 'Ferrari', 2, Decimal('199'), None, 'Hydraulics', None, None),
#  (1, 2022, 1081, 'Azerbaijan Grand Prix', 'Lewis Hamilton', 6, Decimal('62'), None, 'Mercedes', 3, Decimal('161'), None, 'Finished', None, 2),
#  (846, 2022, 1081, 'Azerbaijan Grand Prix', 'Lando Norris', 7, Decimal('50'), None, 'McLaren', 4, Decimal('65'), None, 'Finished', None, 1),
#  (822, 2022, 1081, 'Azerbaijan Grand Prix', 'Valtteri Bottas', 8, Decimal('40'), None, 'Alfa Romeo', 6, Decimal('41'), None, '+1 Lap', None, 1),
#  (839, 2022, 1081, 'Azerbaijan Grand Prix', 'Esteban Ocon', 9, Decimal('31'), None, 'Alpine F1 Team', 5, Decimal('47'), None, 'Finished', None, 1),
#  (842, 2022, 1081, 'Azerbaijan Grand Prix', 'Pierre Gasly', 10, Decimal('16'), None, 'AlphaTauri', 7, Decimal('27'), None, 'Finished', None, 1),
#  (4, 2022, 1081, 'Azerbaijan Grand Prix', 'Fernando Alonso', 11, Decimal('16'), None, 'Alpine F1 Team', 5, Decimal('47'), None, 'Finished', None, 1),
#  (825, 2022, 1081, 'Azerbaijan Grand Prix', 'Kevin Magnussen', 12, Decimal('15'), None, 'Haas F1 Team', 8, Decimal('15'), None, 'Power Unit', None, 1),
#  (817, 2022, 1081, 'Azerbaijan Grand Prix', 'Daniel Ricciardo', 13, Decimal('15'), None, 'McLaren', 4, Decimal('65'), None, 'Finished', None, 1),
#  (20, 2022, 1081, 'Azerbaijan Grand Prix', 'Sebastian Vettel', 14, Decimal('13'), None, 'Aston Martin', 9, Decimal('15'), None, 'Finished', None, 1),
#  (852, 2022, 1081, 'Azerbaijan Grand Prix', 'Yuki Tsunoda', 15, Decimal('11'), None, 'AlphaTauri', 7, Decimal('27'), None, '+1 Lap', None, 2),
#  (848, 2022, 1081, 'Azerbaijan Grand Prix', 'Alexander Albon', 16, Decimal('3'), None, 'Williams', 10, Decimal('3'), None, '+1 Lap', None, 2),
#  (840, 2022, 1081, 'Azerbaijan Grand Prix', 'Lance Stroll', 17, Decimal('2'), None, 'Aston Martin', 9, Decimal('15'), None, 'Vibrations', None, 1),
#  (855, 2022, 1081, 'Azerbaijan Grand Prix', 'Guanyu Zhou', 18, Decimal('1'), None, 'Alfa Romeo', 6, Decimal('41'), None, 'Hydraulics', None, 1),
#  (854, 2022, 1081, 'Azerbaijan Grand Prix', 'Mick Schumacher', 19, Decimal('0'), None, 'Haas F1 Team', 8, Decimal('15'), None, '+1 Lap', None, 2),
#  (849, 2022, 1081, 'Azerbaijan Grand Prix', 'Nicholas Latifi', 21, Decimal('0'), None, 'Williams', 10, Decimal('3'), None, '+1 Lap', None, 2),
#  (830, 2022, 1082, 'Canadian Grand Prix', 'Max Verstappen', 1, Decimal('175'), 'Winner', 'Red Bull', 1, Decimal('304'), 'Team Winner', 'Finished', None, 2),
#  (815, 2022, 1082, 'Canadian Grand Prix', 'Sergio Pérez', 2, Decimal('129'), None, 'Red Bull', 1, Decimal('304'), 'Team Winner', 'Gearbox', None, None),
#  (844, 2022, 1082, 'Canadian Grand Prix', 'Charles Leclerc', 3, Decimal('126'), None, 'Ferrari', 2, Decimal('228'), None, 'Finished', None, 1),
#  (847, 2022, 1082, 'Canadian Grand Prix', 'George Russell', 4, Decimal('111'), None, 'Mercedes', 3, Decimal('188'), None, 'Finished', None, 2),
#  (832, 2022, 1082, 'Canadian Grand Prix', 'Carlos Sainz', 5, Decimal('102'), None, 'Ferrari', 2, Decimal('228'), None, 'Finished', 'Fastest Lap', 2),
#  (1, 2022, 1082, 'Canadian Grand Prix', 'Lewis Hamilton', 6, Decimal('77'), None, 'Mercedes', 3, Decimal('188'), None, 'Finished', None, 2),
#  (846, 2022, 1082, 'Canadian Grand Prix', 'Lando Norris', 7, Decimal('50'), None, 'McLaren', 4, Decimal('65'), None, 'Finished', None, 2),
#  (822, 2022, 1082, 'Canadian Grand Prix', 'Valtteri Bottas', 8, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Finished', None, 1),
#  (839, 2022, 1082, 'Canadian Grand Prix', 'Esteban Ocon', 9, Decimal('39'), None, 'Alpine F1 Team', 5, Decimal('57'), None, 'Finished', None, 2),
#  (4, 2022, 1082, 'Canadian Grand Prix', 'Fernando Alonso', 10, Decimal('18'), None, 'Alpine F1 Team', 5, Decimal('57'), None, 'Finished', None, 2),
#  (842, 2022, 1082, 'Canadian Grand Prix', 'Pierre Gasly', 11, Decimal('16'), None, 'AlphaTauri', 7, Decimal('27'), None, 'Finished', None, 2),
#  (825, 2022, 1082, 'Canadian Grand Prix', 'Kevin Magnussen', 12, Decimal('15'), None, 'Haas F1 Team', 9, Decimal('15'), None, 'Finished', None, 1),
#  (817, 2022, 1082, 'Canadian Grand Prix', 'Daniel Ricciardo', 13, Decimal('15'), None, 'McLaren', 4, Decimal('65'), None, 'Finished', None, 2),
#  (20, 2022, 1082, 'Canadian Grand Prix', 'Sebastian Vettel', 14, Decimal('13'), None, 'Aston Martin', 8, Decimal('16'), None, 'Finished', None, 2),
#  (852, 2022, 1082, 'Canadian Grand Prix', 'Yuki Tsunoda', 15, Decimal('11'), None, 'AlphaTauri', 7, Decimal('27'), None, 'Accident', None, 2),
#  (855, 2022, 1082, 'Canadian Grand Prix', 'Guanyu Zhou', 16, Decimal('5'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Finished', None, 2),
#  (848, 2022, 1082, 'Canadian Grand Prix', 'Alexander Albon', 17, Decimal('3'), None, 'Williams', 10, Decimal('3'), None, 'Finished', None, 2),
#  (840, 2022, 1082, 'Canadian Grand Prix', 'Lance Stroll', 18, Decimal('3'), None, 'Aston Martin', 8, Decimal('16'), None, 'Finished', None, 1),
#  (854, 2022, 1082, 'Canadian Grand Prix', 'Mick Schumacher', 19, Decimal('0'), None, 'Haas F1 Team', 9, Decimal('15'), None, 'Engine', None, None),
#  (849, 2022, 1082, 'Canadian Grand Prix', 'Nicholas Latifi', 21, Decimal('0'), None, 'Williams', 10, Decimal('3'), None, 'Finished', None, 2),
#  (830, 2022, 1083, 'British Grand Prix', 'Max Verstappen', 1, Decimal('181'), 'Winner', 'Red Bull', 1, Decimal('328'), 'Team Winner', 'Finished', None, 4),
#  (815, 2022, 1083, 'British Grand Prix', 'Sergio Pérez', 2, Decimal('147'), None, 'Red Bull', 1, Decimal('328'), 'Team Winner', 'Finished', None, 3),
#  (844, 2022, 1083, 'British Grand Prix', 'Charles Leclerc', 3, Decimal('138'), None, 'Ferrari', 2, Decimal('265'), None, 'Finished', None, 2),
#  (832, 2022, 1083, 'British Grand Prix', 'Carlos Sainz', 4, Decimal('127'), None, 'Ferrari', 2, Decimal('265'), None, 'Finished', None, 3),
#  (847, 2022, 1083, 'British Grand Prix', 'George Russell', 5, Decimal('111'), None, 'Mercedes', 3, Decimal('204'), None, 'Collision', None, None),
#  (1, 2022, 1083, 'British Grand Prix', 'Lewis Hamilton', 6, Decimal('93'), None, 'Mercedes', 3, Decimal('204'), None, 'Finished', 'Fastest Lap', 3),
#  (846, 2022, 1083, 'British Grand Prix', 'Lando Norris', 7, Decimal('58'), None, 'McLaren', 4, Decimal('73'), None, 'Finished', None, 3),
#  (822, 2022, 1083, 'British Grand Prix', 'Valtteri Bottas', 8, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Gearbox', None, 1),
#  (839, 2022, 1083, 'British Grand Prix', 'Esteban Ocon', 9, Decimal('39'), None, 'Alpine F1 Team', 5, Decimal('67'), None, 'Fuel pump', None, 2),
#  (4, 2022, 1083, 'British Grand Prix', 'Fernando Alonso', 10, Decimal('28'), None, 'Alpine F1 Team', 5, Decimal('67'), None, 'Finished', None, 3),
#  (842, 2022, 1083, 'British Grand Prix', 'Pierre Gasly', 11, Decimal('16'), None, 'AlphaTauri', 7, Decimal('27'), None, 'Collision damage', None, 2),
#  (825, 2022, 1083, 'British Grand Prix', 'Kevin Magnussen', 12, Decimal('16'), None, 'Haas F1 Team', 8, Decimal('20'), None, 'Finished', None, 2),
#  (20, 2022, 1083, 'British Grand Prix', 'Sebastian Vettel', 13, Decimal('15'), None, 'Aston Martin', 9, Decimal('18'), None, 'Finished', None, 3),
#  (817, 2022, 1083, 'British Grand Prix', 'Daniel Ricciardo', 14, Decimal('15'), None, 'McLaren', 4, Decimal('73'), None, 'Finished', None, 4),
#  (852, 2022, 1083, 'British Grand Prix', 'Yuki Tsunoda', 15, Decimal('11'), None, 'AlphaTauri', 7, Decimal('27'), None, 'Finished', None, 3),
#  (855, 2022, 1083, 'British Grand Prix', 'Guanyu Zhou', 16, Decimal('5'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Collision', None, None),
#  (854, 2022, 1083, 'British Grand Prix', 'Mick Schumacher', 17, Decimal('4'), None, 'Haas F1 Team', 8, Decimal('20'), None, 'Finished', None, 3),
#  (848, 2022, 1083, 'British Grand Prix', 'Alexander Albon', 18, Decimal('3'), None, 'Williams', 10, Decimal('3'), None, 'Collision', None, None),
#  (840, 2022, 1083, 'British Grand Prix', 'Lance Stroll', 19, Decimal('3'), None, 'Aston Martin', 9, Decimal('18'), None, 'Finished', None, 3),
#  (849, 2022, 1083, 'British Grand Prix', 'Nicholas Latifi', 20, Decimal('0'), None, 'Williams', 10, Decimal('3'), None, 'Finished', None, 3),
#  (830, 2022, 1084, 'Austrian Grand Prix', 'Max Verstappen', 1, Decimal('208'), 'Winner', 'Red Bull', 1, Decimal('359'), 'Team Winner', 'Finished', 'Fastest Lap', 3),
#  (844, 2022, 1084, 'Austrian Grand Prix', 'Charles Leclerc', 2, Decimal('170'), None, 'Ferrari', 2, Decimal('303'), None, 'Finished', None, 3),
#  (815, 2022, 1084, 'Austrian Grand Prix', 'Sergio Pérez', 3, Decimal('151'), None, 'Red Bull', 1, Decimal('359'), 'Team Winner', 'Collision damage', None, 1),
#  (832, 2022, 1084, 'Austrian Grand Prix', 'Carlos Sainz', 4, Decimal('133'), None, 'Ferrari', 2, Decimal('303'), None, 'Power Unit', None, 2),
#  (847, 2022, 1084, 'Austrian Grand Prix', 'George Russell', 5, Decimal('128'), None, 'Mercedes', 3, Decimal('237'), None, 'Finished', None, 2),
#  (1, 2022, 1084, 'Austrian Grand Prix', 'Lewis Hamilton', 6, Decimal('109'), None, 'Mercedes', 3, Decimal('237'), None, 'Finished', None, 2),
#  (846, 2022, 1084, 'Austrian Grand Prix', 'Lando Norris', 7, Decimal('64'), None, 'McLaren', 4, Decimal('81'), None, '+1 Lap', None, 2),
#  (839, 2022, 1084, 'Austrian Grand Prix', 'Esteban Ocon', 8, Decimal('52'), None, 'Alpine F1 Team', 5, Decimal('81'), None, 'Finished', None, 2),
#  (822, 2022, 1084, 'Austrian Grand Prix', 'Valtteri Bottas', 9, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('51'), None, '+1 Lap', None, 2),
#  (4, 2022, 1084, 'Austrian Grand Prix', 'Fernando Alonso', 10, Decimal('29'), None, 'Alpine F1 Team', 5, Decimal('81'), None, '+1 Lap', None, 3),
#  (825, 2022, 1084, 'Austrian Grand Prix', 'Kevin Magnussen', 11, Decimal('22'), None, 'Haas F1 Team', 7, Decimal('34'), None, '+1 Lap', None, 2),
#  (817, 2022, 1084, 'Austrian Grand Prix', 'Daniel Ricciardo', 12, Decimal('17'), None, 'McLaren', 4, Decimal('81'), None, '+1 Lap', None, 2),
#  (842, 2022, 1084, 'Austrian Grand Prix', 'Pierre Gasly', 13, Decimal('16'), None, 'AlphaTauri', 8, Decimal('27'), None, '+1 Lap', None, 2),
#  (20, 2022, 1084, 'Austrian Grand Prix', 'Sebastian Vettel', 14, Decimal('15'), None, 'Aston Martin', 9, Decimal('18'), None, '+1 Lap', None, 2),
#  (854, 2022, 1084, 'Austrian Grand Prix', 'Mick Schumacher', 15, Decimal('12'), None, 'Haas F1 Team', 7, Decimal('34'), None, '+1 Lap', None, 2),
#  (852, 2022, 1084, 'Austrian Grand Prix', 'Yuki Tsunoda', 16, Decimal('11'), None, 'AlphaTauri', 8, Decimal('27'), None, '+1 Lap', None, 2),
#  (855, 2022, 1084, 'Austrian Grand Prix', 'Guanyu Zhou', 17, Decimal('5'), None, 'Alfa Romeo', 6, Decimal('51'), None, '+1 Lap', None, 2),
#  (848, 2022, 1084, 'Austrian Grand Prix', 'Alexander Albon', 18, Decimal('3'), None, 'Williams', 10, Decimal('3'), None, '+1 Lap', None, 2),
#  (840, 2022, 1084, 'Austrian Grand Prix', 'Lance Stroll', 19, Decimal('3'), None, 'Aston Martin', 9, Decimal('18'), None, '+1 Lap', None, 2),
#  (849, 2022, 1084, 'Austrian Grand Prix', 'Nicholas Latifi', 20, Decimal('0'), None, 'Williams', 10, Decimal('3'), None, 'Undertray', None, 2),
#  (830, 2022, 1085, 'French Grand Prix', 'Max Verstappen', 1, Decimal('233'), 'Winner', 'Red Bull', 1, Decimal('396'), 'Team Winner', 'Finished', None, 1),
#  (844, 2022, 1085, 'French Grand Prix', 'Charles Leclerc', 2, Decimal('170'), None, 'Ferrari', 2, Decimal('314'), None, 'Accident', None, None),
#  (815, 2022, 1085, 'French Grand Prix', 'Sergio Pérez', 3, Decimal('163'), None, 'Red Bull', 1, Decimal('396'), 'Team Winner', 'Finished', None, 1),
#  (832, 2022, 1085, 'French Grand Prix', 'Carlos Sainz', 4, Decimal('144'), None, 'Ferrari', 2, Decimal('314'), None, 'Finished', 'Fastest Lap', 2),
#  (847, 2022, 1085, 'French Grand Prix', 'George Russell', 5, Decimal('143'), None, 'Mercedes', 3, Decimal('270'), None, 'Finished', None, 1),
#  (1, 2022, 1085, 'French Grand Prix', 'Lewis Hamilton', 6, Decimal('127'), None, 'Mercedes', 3, Decimal('270'), None, 'Finished', None, 1),
#  (846, 2022, 1085, 'French Grand Prix', 'Lando Norris', 7, Decimal('70'), None, 'McLaren', 5, Decimal('89'), None, 'Finished', None, 1),
#  (839, 2022, 1085, 'French Grand Prix', 'Esteban Ocon', 8, Decimal('56'), None, 'Alpine F1 Team', 4, Decimal('93'), None, 'Finished', None, 1),
#  (822, 2022, 1085, 'French Grand Prix', 'Valtteri Bottas', 9, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Finished', None, 2),
#  (4, 2022, 1085, 'French Grand Prix', 'Fernando Alonso', 10, Decimal('37'), None, 'Alpine F1 Team', 4, Decimal('93'), None, 'Finished', None, 1),
#  (825, 2022, 1085, 'French Grand Prix', 'Kevin Magnussen', 11, Decimal('22'), None, 'Haas F1 Team', 7, Decimal('34'), None, 'Collision damage', None, 2),
#  (817, 2022, 1085, 'French Grand Prix', 'Daniel Ricciardo', 12, Decimal('19'), None, 'McLaren', 5, Decimal('89'), None, 'Finished', None, 1),
#  (842, 2022, 1085, 'French Grand Prix', 'Pierre Gasly', 13, Decimal('16'), None, 'AlphaTauri', 8, Decimal('27'), None, 'Finished', None, 1),
#  (20, 2022, 1085, 'French Grand Prix', 'Sebastian Vettel', 14, Decimal('15'), None, 'Aston Martin', 9, Decimal('19'), None, 'Finished', None, 1),
#  (854, 2022, 1085, 'French Grand Prix', 'Mick Schumacher', 15, Decimal('12'), None, 'Haas F1 Team', 7, Decimal('34'), None, 'Finished', None, 2),
#  (852, 2022, 1085, 'French Grand Prix', 'Yuki Tsunoda', 16, Decimal('11'), None, 'AlphaTauri', 8, Decimal('27'), None, 'Undertray', None, 1),
#  (855, 2022, 1085, 'French Grand Prix', 'Guanyu Zhou', 17, Decimal('5'), None, 'Alfa Romeo', 6, Decimal('51'), None, '+6 Laps', None, 2),
#  (840, 2022, 1085, 'French Grand Prix', 'Lance Stroll', 18, Decimal('4'), None, 'Aston Martin', 9, Decimal('19'), None, 'Finished', None, 1),
#  (848, 2022, 1085, 'French Grand Prix', 'Alexander Albon', 19, Decimal('3'), None, 'Williams', 10, Decimal('3'), None, 'Finished', None, 1),
#  (849, 2022, 1085, 'French Grand Prix', 'Nicholas Latifi', 20, Decimal('0'), None, 'Williams', 10, Decimal('3'), None, 'Collision damage', None, 2),
#  (830, 2022, 1086, 'Hungarian Grand Prix', 'Max Verstappen', 1, Decimal('258'), 'Winner', 'Red Bull', 1, Decimal('431'), 'Team Winner', 'Finished', None, 2),
#  (844, 2022, 1086, 'Hungarian Grand Prix', 'Charles Leclerc', 2, Decimal('178'), None, 'Ferrari', 2, Decimal('334'), None, 'Finished', None, 3),
#  (815, 2022, 1086, 'Hungarian Grand Prix', 'Sergio Pérez', 3, Decimal('173'), None, 'Red Bull', 1, Decimal('431'), 'Team Winner', 'Finished', None, 2),
#  (847, 2022, 1086, 'Hungarian Grand Prix', 'George Russell', 4, Decimal('158'), None, 'Mercedes', 3, Decimal('304'), None, 'Finished', None, 2),
#  (832, 2022, 1086, 'Hungarian Grand Prix', 'Carlos Sainz', 5, Decimal('156'), None, 'Ferrari', 2, Decimal('334'), None, 'Finished', None, 2),
#  (1, 2022, 1086, 'Hungarian Grand Prix', 'Lewis Hamilton', 6, Decimal('146'), None, 'Mercedes', 3, Decimal('304'), None, 'Finished', 'Fastest Lap', 2),
#  (846, 2022, 1086, 'Hungarian Grand Prix', 'Lando Norris', 7, Decimal('76'), None, 'McLaren', 5, Decimal('95'), None, 'Finished', None, 2),
#  (839, 2022, 1086, 'Hungarian Grand Prix', 'Esteban Ocon', 8, Decimal('58'), None, 'Alpine F1 Team', 4, Decimal('99'), None, '+1 Lap', None, 1),
#  (822, 2022, 1086, 'Hungarian Grand Prix', 'Valtteri Bottas', 9, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Power Unit', None, 1),
#  (4, 2022, 1086, 'Hungarian Grand Prix', 'Fernando Alonso', 10, Decimal('41'), None, 'Alpine F1 Team', 4, Decimal('99'), None, '+1 Lap', None, 1),
#  (825, 2022, 1086, 'Hungarian Grand Prix', 'Kevin Magnussen', 11, Decimal('22'), None, 'Haas F1 Team', 7, Decimal('34'), None, '+1 Lap', None, 3),
#  (817, 2022, 1086, 'Hungarian Grand Prix', 'Daniel Ricciardo', 12, Decimal('19'), None, 'McLaren', 5, Decimal('95'), None, '+1 Lap', None, 2),
#  (842, 2022, 1086, 'Hungarian Grand Prix', 'Pierre Gasly', 13, Decimal('16'), None, 'AlphaTauri', 8, Decimal('27'), None, '+1 Lap', None, 2),
#  (20, 2022, 1086, 'Hungarian Grand Prix', 'Sebastian Vettel', 14, Decimal('16'), None, 'Aston Martin', 9, Decimal('20'), None, '+1 Lap', None, 2),
#  (854, 2022, 1086, 'Hungarian Grand Prix', 'Mick Schumacher', 15, Decimal('12'), None, 'Haas F1 Team', 7, Decimal('34'), None, '+1 Lap', None, 2),
#  (852, 2022, 1086, 'Hungarian Grand Prix', 'Yuki Tsunoda', 16, Decimal('11'), None, 'AlphaTauri', 8, Decimal('27'), None, '+2 Laps', None, 3),
#  (855, 2022, 1086, 'Hungarian Grand Prix', 'Guanyu Zhou', 17, Decimal('5'), None, 'Alfa Romeo', 6, Decimal('51'), None, '+1 Lap', None, 2),
#  (840, 2022, 1086, 'Hungarian Grand Prix', 'Lance Stroll', 18, Decimal('4'), None, 'Aston Martin', 9, Decimal('20'), None, '+1 Lap', None, 2),
#  (848, 2022, 1086, 'Hungarian Grand Prix', 'Alexander Albon', 19, Decimal('3'), None, 'Williams', 10, Decimal('3'), None, '+1 Lap', None, 3),
#  (849, 2022, 1086, 'Hungarian Grand Prix', 'Nicholas Latifi', 20, Decimal('0'), None, 'Williams', 10, Decimal('3'), None, '+1 Lap', None, 3),
#  (830, 2022, 1087, 'Belgian Grand Prix', 'Max Verstappen', 1, Decimal('284'), 'Winner', 'Red Bull', 1, Decimal('475'), 'Team Winner', 'Finished', 'Fastest Lap', 2),
#  (815, 2022, 1087, 'Belgian Grand Prix', 'Sergio Pérez', 2, Decimal('191'), None, 'Red Bull', 1, Decimal('475'), 'Team Winner', 'Finished', None, 2),
#  (844, 2022, 1087, 'Belgian Grand Prix', 'Charles Leclerc', 3, Decimal('186'), None, 'Ferrari', 2, Decimal('357'), None, 'Finished', None, 3),
#  (832, 2022, 1087, 'Belgian Grand Prix', 'Carlos Sainz', 4, Decimal('171'), None, 'Ferrari', 2, Decimal('357'), None, 'Finished', None, 2),
#  (847, 2022, 1087, 'Belgian Grand Prix', 'George Russell', 5, Decimal('170'), None, 'Mercedes', 3, Decimal('316'), None, 'Finished', None, 2),
#  (1, 2022, 1087, 'Belgian Grand Prix', 'Lewis Hamilton', 6, Decimal('146'), None, 'Mercedes', 3, Decimal('316'), None, 'Collision damage', None, None),
#  (846, 2022, 1087, 'Belgian Grand Prix', 'Lando Norris', 7, Decimal('76'), None, 'McLaren', 5, Decimal('95'), None, 'Finished', None, 2),
#  (839, 2022, 1087, 'Belgian Grand Prix', 'Esteban Ocon', 8, Decimal('64'), None, 'Alpine F1 Team', 4, Decimal('115'), None, 'Finished', None, 2),
#  (4, 2022, 1087, 'Belgian Grand Prix', 'Fernando Alonso', 9, Decimal('51'), None, 'Alpine F1 Team', 4, Decimal('115'), None, 'Finished', None, 2),
#  (822, 2022, 1087, 'Belgian Grand Prix', 'Valtteri Bottas', 10, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Accident', None, None),
#  (825, 2022, 1087, 'Belgian Grand Prix', 'Kevin Magnussen', 11, Decimal('22'), None, 'Haas F1 Team', 7, Decimal('34'), None, '+1 Lap', None, 2),
#  (20, 2022, 1087, 'Belgian Grand Prix', 'Sebastian Vettel', 12, Decimal('20'), None, 'Aston Martin', 9, Decimal('24'), None, 'Finished', None, 2),
#  (817, 2022, 1087, 'Belgian Grand Prix', 'Daniel Ricciardo', 13, Decimal('19'), None, 'McLaren', 5, Decimal('95'), None, 'Finished', None, 2),
#  (842, 2022, 1087, 'Belgian Grand Prix', 'Pierre Gasly', 14, Decimal('18'), None, 'AlphaTauri', 8, Decimal('29'), None, 'Finished', None, 2),
#  (854, 2022, 1087, 'Belgian Grand Prix', 'Mick Schumacher', 15, Decimal('12'), None, 'Haas F1 Team', 7, Decimal('34'), None, '+1 Lap', None, 2),
#  (852, 2022, 1087, 'Belgian Grand Prix', 'Yuki Tsunoda', 16, Decimal('11'), None, 'AlphaTauri', 8, Decimal('29'), None, 'Finished', None, 2),
#  (855, 2022, 1087, 'Belgian Grand Prix', 'Guanyu Zhou', 17, Decimal('5'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Finished', None, 2),
#  (848, 2022, 1087, 'Belgian Grand Prix', 'Alexander Albon', 18, Decimal('4'), None, 'Williams', 10, Decimal('4'), None, 'Finished', None, 2),
#  (840, 2022, 1087, 'Belgian Grand Prix', 'Lance Stroll', 19, Decimal('4'), None, 'Aston Martin', 9, Decimal('24'), None, 'Finished', None, 2),
#  (849, 2022, 1087, 'Belgian Grand Prix', 'Nicholas Latifi', 20, Decimal('0'), None, 'Williams', 10, Decimal('4'), None, '+1 Lap', None, 3),
#  (830, 2022, 1088, 'Dutch Grand Prix', 'Max Verstappen', 1, Decimal('310'), 'Winner', 'Red Bull', 1, Decimal('511'), 'Team Winner', 'Finished', 'Fastest Lap', 4),
#  (844, 2022, 1088, 'Dutch Grand Prix', 'Charles Leclerc', 2, Decimal('201'), None, 'Ferrari', 2, Decimal('376'), None, 'Finished', None, 4),
#  (815, 2022, 1088, 'Dutch Grand Prix', 'Sergio Pérez', 3, Decimal('201'), None, 'Red Bull', 1, Decimal('511'), 'Team Winner', 'Finished', None, 4),
#  (847, 2022, 1088, 'Dutch Grand Prix', 'George Russell', 4, Decimal('188'), None, 'Mercedes', 3, Decimal('346'), None, 'Finished', 'Fastest Lap', 3),
#  (832, 2022, 1088, 'Dutch Grand Prix', 'Carlos Sainz', 5, Decimal('175'), None, 'Ferrari', 2, Decimal('376'), None, 'Finished', None, 3),
#  (1, 2022, 1088, 'Dutch Grand Prix', 'Lewis Hamilton', 6, Decimal('158'), None, 'Mercedes', 3, Decimal('346'), None, 'Finished', None, 3),
#  (846, 2022, 1088, 'Dutch Grand Prix', 'Lando Norris', 7, Decimal('82'), None, 'McLaren', 5, Decimal('101'), None, 'Finished', None, 3),
#  (839, 2022, 1088, 'Dutch Grand Prix', 'Esteban Ocon', 8, Decimal('66'), None, 'Alpine F1 Team', 4, Decimal('125'), None, 'Finished', None, 3),
#  (4, 2022, 1088, 'Dutch Grand Prix', 'Fernando Alonso', 9, Decimal('59'), None, 'Alpine F1 Team', 4, Decimal('125'), None, 'Finished', None, 3),
#  (822, 2022, 1088, 'Dutch Grand Prix', 'Valtteri Bottas', 10, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Engine', None, 2),
#  (825, 2022, 1088, 'Dutch Grand Prix', 'Kevin Magnussen', 11, Decimal('22'), None, 'Haas F1 Team', 7, Decimal('34'), None, 'Finished', None, 4),
#  (20, 2022, 1088, 'Dutch Grand Prix', 'Sebastian Vettel', 12, Decimal('20'), None, 'Aston Martin', 9, Decimal('25'), None, 'Finished', None, 4),
#  (817, 2022, 1088, 'Dutch Grand Prix', 'Daniel Ricciardo', 13, Decimal('19'), None, 'McLaren', 5, Decimal('101'), None, 'Finished', None, 5),
#  (842, 2022, 1088, 'Dutch Grand Prix', 'Pierre Gasly', 14, Decimal('18'), None, 'AlphaTauri', 8, Decimal('29'), None, 'Finished', None, 4),
#  (854, 2022, 1088, 'Dutch Grand Prix', 'Mick Schumacher', 15, Decimal('12'), None, 'Haas F1 Team', 7, Decimal('34'), None, 'Finished', None, 4),
#  (852, 2022, 1088, 'Dutch Grand Prix', 'Yuki Tsunoda', 16, Decimal('11'), None, 'AlphaTauri', 8, Decimal('29'), None, 'Differential', None, 3),
#  (855, 2022, 1088, 'Dutch Grand Prix', 'Guanyu Zhou', 17, Decimal('5'), None, 'Alfa Romeo', 6, Decimal('51'), None, 'Finished', None, 4),
#  (840, 2022, 1088, 'Dutch Grand Prix', 'Lance Stroll', 18, Decimal('5'), None, 'Aston Martin', 9, Decimal('25'), None, 'Finished', None, 4),
#  (848, 2022, 1088, 'Dutch Grand Prix', 'Alexander Albon', 19, Decimal('4'), None, 'Williams', 10, Decimal('4'), None, 'Finished', None, 4),
#  (849, 2022, 1088, 'Dutch Grand Prix', 'Nicholas Latifi', 20, Decimal('0'), None, 'Williams', 10, Decimal('4'), None, '+1 Lap', None, 4),
#  (830, 2022, 1089, 'Italian Grand Prix', 'Max Verstappen', 1, Decimal('335'), 'Winner', 'Red Bull', 1, Decimal('545'), 'Team Winner', 'Finished', None, 2),
#  (844, 2022, 1089, 'Italian Grand Prix', 'Charles Leclerc', 2, Decimal('219'), None, 'Ferrari', 2, Decimal('406'), None, 'Finished', None, 3),
#  (815, 2022, 1089, 'Italian Grand Prix', 'Sergio Pérez', 3, Decimal('210'), None, 'Red Bull', 1, Decimal('545'), 'Team Winner', 'Finished', 'Fastest Lap', 2),
#  (847, 2022, 1089, 'Italian Grand Prix', 'George Russell', 4, Decimal('203'), None, 'Mercedes', 3, Decimal('371'), None, 'Finished', None, 2),
#  (832, 2022, 1089, 'Italian Grand Prix', 'Carlos Sainz', 5, Decimal('187'), None, 'Ferrari', 2, Decimal('406'), None, 'Finished', None, 2),
#  (1, 2022, 1089, 'Italian Grand Prix', 'Lewis Hamilton', 6, Decimal('168'), None, 'Mercedes', 3, Decimal('371'), None, 'Finished', None, 1),
#  (846, 2022, 1089, 'Italian Grand Prix', 'Lando Norris', 7, Decimal('88'), None, 'McLaren', 5, Decimal('107'), None, 'Finished', None, 2),
#  (839, 2022, 1089, 'Italian Grand Prix', 'Esteban Ocon', 8, Decimal('66'), None, 'Alpine F1 Team', 4, Decimal('125'), None, 'Finished', None, 1),
#  (4, 2022, 1089, 'Italian Grand Prix', 'Fernando Alonso', 9, Decimal('59'), None, 'Alpine F1 Team', 4, Decimal('125'), None, 'Water pressure', None, None),
#  (822, 2022, 1089, 'Italian Grand Prix', 'Valtteri Bottas', 10, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('52'), None, '+1 Lap', None, 1),
#  (842, 2022, 1089, 'Italian Grand Prix', 'Pierre Gasly', 11, Decimal('22'), None, 'AlphaTauri', 8, Decimal('33'), None, 'Finished', None, 1),
#  (825, 2022, 1089, 'Italian Grand Prix', 'Kevin Magnussen', 12, Decimal('22'), None, 'Haas F1 Team', 7, Decimal('34'), None, '+1 Lap', None, 2),
#  (20, 2022, 1089, 'Italian Grand Prix', 'Sebastian Vettel', 13, Decimal('20'), None, 'Aston Martin', 9, Decimal('25'), None, 'Engine', None, None),
#  (817, 2022, 1089, 'Italian Grand Prix', 'Daniel Ricciardo', 14, Decimal('19'), None, 'McLaren', 5, Decimal('107'), None, 'Oil leak', None, 1),
#  (854, 2022, 1089, 'Italian Grand Prix', 'Mick Schumacher', 15, Decimal('12'), None, 'Haas F1 Team', 7, Decimal('34'), None, 'Finished', None, 1),
#  (852, 2022, 1089, 'Italian Grand Prix', 'Yuki Tsunoda', 16, Decimal('11'), None, 'AlphaTauri', 8, Decimal('33'), None, '+1 Lap', None, 2),
#  (855, 2022, 1089, 'Italian Grand Prix', 'Guanyu Zhou', 17, Decimal('6'), None, 'Alfa Romeo', 6, Decimal('52'), None, 'Finished', None, 1),
#  (840, 2022, 1089, 'Italian Grand Prix', 'Lance Stroll', 18, Decimal('5'), None, 'Aston Martin', 9, Decimal('25'), None, 'Engine', None, 1),
#  (856, 2022, 1089, 'Italian Grand Prix', 'Nyck de Vries', 20, Decimal('2'), None, 'Williams', 10, Decimal('6'), None, 'Finished', None, 1),
#  (849, 2022, 1089, 'Italian Grand Prix', 'Nicholas Latifi', 21, Decimal('0'), None, 'Williams', 10, Decimal('6'), None, '+1 Lap', None, 2),
#  (830, 2022, 1091, 'Singapore Grand Prix', 'Max Verstappen', 1, Decimal('341'), 'Winner', 'Red Bull', 1, Decimal('576'), 'Team Winner', 'Finished', None, 2),
#  (844, 2022, 1091, 'Singapore Grand Prix', 'Charles Leclerc', 2, Decimal('237'), None, 'Ferrari', 2, Decimal('439'), None, 'Finished', None, 1),
#  (815, 2022, 1091, 'Singapore Grand Prix', 'Sergio Pérez', 3, Decimal('235'), None, 'Red Bull', 1, Decimal('576'), 'Team Winner', 'Finished', None, 1),
#  (847, 2022, 1091, 'Singapore Grand Prix', 'George Russell', 4, Decimal('203'), None, 'Mercedes', 3, Decimal('373'), None, '+2 Laps', 'Fastest Lap', 4),
#  (832, 2022, 1091, 'Singapore Grand Prix', 'Carlos Sainz', 5, Decimal('202'), None, 'Ferrari', 2, Decimal('439'), None, 'Finished', None, 1),
#  (1, 2022, 1091, 'Singapore Grand Prix', 'Lewis Hamilton', 6, Decimal('170'), None, 'Mercedes', 3, Decimal('373'), None, 'Finished', None, 1),
#  (846, 2022, 1091, 'Singapore Grand Prix', 'Lando Norris', 7, Decimal('100'), None, 'McLaren', 4, Decimal('129'), None, 'Finished', None, 1),
#  (839, 2022, 1091, 'Singapore Grand Prix', 'Esteban Ocon', 8, Decimal('66'), None, 'Alpine F1 Team', 5, Decimal('125'), None, 'Engine', None, None),
#  (4, 2022, 1091, 'Singapore Grand Prix', 'Fernando Alonso', 9, Decimal('59'), None, 'Alpine F1 Team', 5, Decimal('125'), None, 'Engine', None, None),
# ...
#  (842, 2022, 1091, 'Singapore Grand Prix', 'Pierre Gasly', 13, Decimal('23'), None, 'AlphaTauri', 9, Decimal('34'), None, 'Finished', None, 1),
#  (825, 2022, 1091, 'Singapore Grand Prix', 'Kevin Magnussen', 14, Decimal('22'), None, 'Haas F1 Team', 8, Decimal('34'), None, 'Finished', None, 2),
#  (840, 2022, 1091, 'Singapore Grand Prix', 'Lance Stroll', 15, Decimal('13'), None, 'Aston Martin', 7, Decimal('37'), None, 'Finished', None, 1),
#  (854, 2022, 1091, 'Singapore Grand Prix', 'Mick Schumacher', 16, Decimal('12'), None, 'Haas F1 Team', 8, Decimal('34'), None, '+1 Lap', None, 2),
#  (852, 2022, 1091, 'Singapore Grand Prix', 'Yuki Tsunoda', 17, Decimal('11'), None, 'AlphaTauri', 9, Decimal('34'), None, 'Accident', None, 1),
#  (855, 2022, 1091, 'Singapore Grand Prix', 'Guanyu Zhou', 18, Decimal('6'), None, 'Alfa Romeo', 6, Decimal('52'), None, 'Collision', None, None),
#  (848, 2022, 1091, 'Singapore Grand Prix', 'Alexander Albon', 19, Decimal('4'), None, 'Williams', 10, Decimal('6'), None, 'Collision damage', None, None),
#  (849, 2022, 1091, 'Singapore Grand Prix', 'Nicholas Latifi', 21, Decimal('0'), None, 'Williams', 10, Decimal('6'), None, 'Collision damage', None, None),
#  (830, 2022, 1092, 'Japanese Grand Prix', 'Max Verstappen', 1, Decimal('366'), 'Winner', 'Red Bull', 1, Decimal('619'), 'Team Winner', 'Finished', None, 2),
#  (815, 2022, 1092, 'Japanese Grand Prix', 'Sergio Pérez', 2, Decimal('253'), None, 'Red Bull', 1, Decimal('619'), 'Team Winner', 'Finished', None, 2),
#  (844, 2022, 1092, 'Japanese Grand Prix', 'Charles Leclerc', 3, Decimal('252'), None, 'Ferrari', 2, Decimal('454'), None, 'Finished', None, 2),
#  (847, 2022, 1092, 'Japanese Grand Prix', 'George Russell', 4, Decimal('207'), None, 'Mercedes', 3, Decimal('387'), None, 'Finished', None, 2),
#  (832, 2022, 1092, 'Japanese Grand Prix', 'Carlos Sainz', 5, Decimal('202'), None, 'Ferrari', 2, Decimal('454'), None, 'Accident', None, None),
#  (1, 2022, 1092, 'Japanese Grand Prix', 'Lewis Hamilton', 6, Decimal('180'), None, 'Mercedes', 3, Decimal('387'), None, 'Finished', None, 2),
#  (846, 2022, 1092, 'Japanese Grand Prix', 'Lando Norris', 7, Decimal('101'), None, 'McLaren', 5, Decimal('130'), None, 'Finished', None, 2),
#  (839, 2022, 1092, 'Japanese Grand Prix', 'Esteban Ocon', 8, Decimal('78'), None, 'Alpine F1 Team', 4, Decimal('143'), None, 'Finished', None, 2),
#  (4, 2022, 1092, 'Japanese Grand Prix', 'Fernando Alonso', 9, Decimal('65'), None, 'Alpine F1 Team', 4, Decimal('143'), None, 'Finished', 'Fastest Lap', 3),
#  (822, 2022, 1092, 'Japanese Grand Prix', 'Valtteri Bottas', 10, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('52'), None, 'Finished', None, 2),
#  (20, 2022, 1092, 'Japanese Grand Prix', 'Sebastian Vettel', 11, Decimal('32'), None, 'Aston Martin', 7, Decimal('45'), None, 'Finished', None, 2),
#  (817, 2022, 1092, 'Japanese Grand Prix', 'Daniel Ricciardo', 12, Decimal('29'), None, 'McLaren', 5, Decimal('130'), None, 'Finished', None, 2),
#  (842, 2022, 1092, 'Japanese Grand Prix', 'Pierre Gasly', 13, Decimal('23'), None, 'AlphaTauri', 9, Decimal('34'), None, 'Finished', None, 4),
#  (825, 2022, 1092, 'Japanese Grand Prix', 'Kevin Magnussen', 14, Decimal('22'), None, 'Haas F1 Team', 8, Decimal('34'), None, 'Finished', None, 2),
#  (840, 2022, 1092, 'Japanese Grand Prix', 'Lance Stroll', 15, Decimal('13'), None, 'Aston Martin', 7, Decimal('45'), None, 'Finished', None, 3),
#  (854, 2022, 1092, 'Japanese Grand Prix', 'Mick Schumacher', 16, Decimal('12'), None, 'Haas F1 Team', 8, Decimal('34'), None, 'Finished', None, 2),
#  (852, 2022, 1092, 'Japanese Grand Prix', 'Yuki Tsunoda', 17, Decimal('11'), None, 'AlphaTauri', 9, Decimal('34'), None, 'Finished', None, 3),
#  (855, 2022, 1092, 'Japanese Grand Prix', 'Guanyu Zhou', 18, Decimal('6'), None, 'Alfa Romeo', 6, Decimal('52'), None, 'Finished', 'Fastest Lap', 3),
#  (848, 2022, 1092, 'Japanese Grand Prix', 'Alexander Albon', 19, Decimal('4'), None, 'Williams', 10, Decimal('8'), None, 'Hydraulics', None, None),
#  (849, 2022, 1092, 'Japanese Grand Prix', 'Nicholas Latifi', 20, Decimal('2'), None, 'Williams', 10, Decimal('8'), None, 'Finished', None, 2),
#  (830, 2022, 1093, 'United States Grand Prix', 'Max Verstappen', 1, Decimal('391'), 'Winner', 'Red Bull', 1, Decimal('656'), 'Team Winner', 'Finished', None, 2),
#  (844, 2022, 1093, 'United States Grand Prix', 'Charles Leclerc', 2, Decimal('267'), None, 'Ferrari', 2, Decimal('469'), None, 'Finished', None, 2),
#  (815, 2022, 1093, 'United States Grand Prix', 'Sergio Pérez', 3, Decimal('265'), None, 'Red Bull', 1, Decimal('656'), 'Team Winner', 'Finished', None, 2),
#  (847, 2022, 1093, 'United States Grand Prix', 'George Russell', 4, Decimal('218'), None, 'Mercedes', 3, Decimal('416'), None, 'Finished', 'Fastest Lap', 3),
#  (832, 2022, 1093, 'United States Grand Prix', 'Carlos Sainz', 5, Decimal('202'), None, 'Ferrari', 2, Decimal('469'), None, 'Collision damage', None, None),
#  (1, 2022, 1093, 'United States Grand Prix', 'Lewis Hamilton', 6, Decimal('198'), None, 'Mercedes', 3, Decimal('416'), None, 'Finished', None, 2),
#  (846, 2022, 1093, 'United States Grand Prix', 'Lando Norris', 7, Decimal('109'), None, 'McLaren', 5, Decimal('138'), None, 'Finished', None, 2),
#  (839, 2022, 1093, 'United States Grand Prix', 'Esteban Ocon', 8, Decimal('78'), None, 'Alpine F1 Team', 4, Decimal('149'), None, 'Finished', None, 2),
#  (4, 2022, 1093, 'United States Grand Prix', 'Fernando Alonso', 9, Decimal('71'), None, 'Alpine F1 Team', 4, Decimal('149'), None, 'Finished', None, 2),
#  (822, 2022, 1093, 'United States Grand Prix', 'Valtteri Bottas', 10, Decimal('46'), None, 'Alfa Romeo', 6, Decimal('52'), None, 'Spun off', None, 1),
#  (20, 2022, 1093, 'United States Grand Prix', 'Sebastian Vettel', 11, Decimal('36'), None, 'Aston Martin', 7, Decimal('49'), None, 'Finished', None, 2),
#  (817, 2022, 1093, 'United States Grand Prix', 'Daniel Ricciardo', 12, Decimal('29'), None, 'McLaren', 5, Decimal('138'), None, 'Finished', None, 2),
#  (825, 2022, 1093, 'United States Grand Prix', 'Kevin Magnussen', 13, Decimal('24'), None, 'Haas F1 Team', 8, Decimal('36'), None, 'Finished', None, 1),
#  (842, 2022, 1093, 'United States Grand Prix', 'Pierre Gasly', 14, Decimal('23'), None, 'AlphaTauri', 9, Decimal('35'), None, 'Finished', None, 2),
#  (840, 2022, 1093, 'United States Grand Prix', 'Lance Stroll', 15, Decimal('13'), None, 'Aston Martin', 7, Decimal('49'), None, 'Collision', None, 1),
#  (854, 2022, 1093, 'United States Grand Prix', 'Mick Schumacher', 16, Decimal('12'), None, 'Haas F1 Team', 8, Decimal('36'), None, 'Finished', None, 2),
#  (852, 2022, 1093, 'United States Grand Prix', 'Yuki Tsunoda', 17, Decimal('12'), None, 'AlphaTauri', 9, Decimal('35'), None, 'Finished', None, 2),
#  (855, 2022, 1093, 'United States Grand Prix', 'Guanyu Zhou', 18, Decimal('6'), None, 'Alfa Romeo', 6, Decimal('52'), None, 'Finished', None, 2),
#  (848, 2022, 1093, 'United States Grand Prix', 'Alexander Albon', 19, Decimal('4'), None, 'Williams', 10, Decimal('8'), None, 'Finished', None, 2),
#  (849, 2022, 1093, 'United States Grand Prix', 'Nicholas Latifi', 20, Decimal('2'), None, 'Williams', 10, Decimal('8'), None, 'Finished', None, 2),
#  (830, 2022, 1094, 'Mexico City Grand Prix', 'Max Verstappen', 1, Decimal('416'), 'Winner', 'Red Bull', 1, Decimal('696'), 'Team Winner', 'Finished', None, 1),
#  (815, 2022, 1094, 'Mexico City Grand Prix', 'Sergio Pérez', 2, Decimal('280'), None, 'Red Bull', 1, Decimal('696'), 'Team Winner', 'Finished', None, 1),
#  (844, 2022, 1094, 'Mexico City Grand Prix', 'Charles Leclerc', 3, Decimal('275'), None, 'Ferrari', 2, Decimal('487'), None, 'Finished', None, 1),
#  (847, 2022, 1094, 'Mexico City Grand Prix', 'George Russell', 4, Decimal('231'), None, 'Mercedes', 3, Decimal('447'), None, 'Finished', 'Fastest Lap', 2),
#  (1, 2022, 1094, 'Mexico City Grand Prix', 'Lewis Hamilton', 5, Decimal('216'), None, 'Mercedes', 3, Decimal('447'), None, 'Finished', None, 1),
#  (832, 2022, 1094, 'Mexico City Grand Prix', 'Carlos Sainz', 6, Decimal('212'), None, 'Ferrari', 2, Decimal('487'), None, 'Finished', None, 1),
#  (846, 2022, 1094, 'Mexico City Grand Prix', 'Lando Norris', 7, Decimal('111'), None, 'McLaren', 5, Decimal('146'), None, '+1 Lap', None, 1),
#  (839, 2022, 1094, 'Mexico City Grand Prix', 'Esteban Ocon', 8, Decimal('82'), None, 'Alpine F1 Team', 4, Decimal('153'), None, '+1 Lap', None, 1),
#  (4, 2022, 1094, 'Mexico City Grand Prix', 'Fernando Alonso', 9, Decimal('71'), None, 'Alpine F1 Team', 4, Decimal('153'), None, 'Engine', None, 1),
#  (822, 2022, 1094, 'Mexico City Grand Prix', 'Valtteri Bottas', 10, Decimal('47'), None, 'Alfa Romeo', 6, Decimal('53'), None, '+1 Lap', None, 1),
#  (20, 2022, 1094, 'Mexico City Grand Prix', 'Sebastian Vettel', 11, Decimal('36'), None, 'Aston Martin', 7, Decimal('49'), None, '+1 Lap', None, 1),
#  (817, 2022, 1094, 'Mexico City Grand Prix', 'Daniel Ricciardo', 12, Decimal('35'), None, 'McLaren', 5, Decimal('146'), None, '+1 Lap', None, 1),
#  (825, 2022, 1094, 'Mexico City Grand Prix', 'Kevin Magnussen', 13, Decimal('24'), None, 'Haas F1 Team', 8, Decimal('36'), None, '+1 Lap', None, 1),
#  (842, 2022, 1094, 'Mexico City Grand Prix', 'Pierre Gasly', 14, Decimal('23'), None, 'AlphaTauri', 9, Decimal('35'), None, '+1 Lap', None, 1),
#  (840, 2022, 1094, 'Mexico City Grand Prix', 'Lance Stroll', 15, Decimal('13'), None, 'Aston Martin', 7, Decimal('49'), None, '+1 Lap', None, 2),
#  (854, 2022, 1094, 'Mexico City Grand Prix', 'Mick Schumacher', 16, Decimal('12'), None, 'Haas F1 Team', 8, Decimal('36'), None, '+1 Lap', None, 1),
#  (852, 2022, 1094, 'Mexico City Grand Prix', 'Yuki Tsunoda', 17, Decimal('12'), None, 'AlphaTauri', 9, Decimal('35'), None, 'Collision damage', None, 1),
#  (855, 2022, 1094, 'Mexico City Grand Prix', 'Guanyu Zhou', 18, Decimal('6'), None, 'Alfa Romeo', 6, Decimal('53'), None, '+1 Lap', None, 1),
#  (848, 2022, 1094, 'Mexico City Grand Prix', 'Alexander Albon', 19, Decimal('4'), None, 'Williams', 10, Decimal('8'), None, '+1 Lap', None, 1),
#  (849, 2022, 1094, 'Mexico City Grand Prix', 'Nicholas Latifi', 20, Decimal('2'), None, 'Williams', 10, Decimal('8'), None, '+2 Laps', None, 2),
#  (830, 2022, 1095, 'Brazilian Grand Prix', 'Max Verstappen', 1, Decimal('429'), 'Winner', 'Red Bull', 1, Decimal('719'), 'Team Winner', 'Finished', None, 3),
#  (844, 2022, 1095, 'Brazilian Grand Prix', 'Charles Leclerc', 2, Decimal('290'), None, 'Ferrari', 2, Decimal('524'), None, 'Finished', None, 3),
#  (815, 2022, 1095, 'Brazilian Grand Prix', 'Sergio Pérez', 3, Decimal('290'), None, 'Red Bull', 1, Decimal('719'), 'Team Winner', 'Finished', None, 2),
#  (847, 2022, 1095, 'Brazilian Grand Prix', 'George Russell', 4, Decimal('265'), None, 'Mercedes', 3, Decimal('505'), None, 'Finished', 'Fastest Lap', 2),
#  (1, 2022, 1095, 'Brazilian Grand Prix', 'Lewis Hamilton', 5, Decimal('240'), None, 'Mercedes', 3, Decimal('505'), None, 'Finished', None, 2),
#  (832, 2022, 1095, 'Brazilian Grand Prix', 'Carlos Sainz', 6, Decimal('234'), None, 'Ferrari', 2, Decimal('524'), None, 'Finished', None, 3),
#  (846, 2022, 1095, 'Brazilian Grand Prix', 'Lando Norris', 7, Decimal('113'), None, 'McLaren', 5, Decimal('148'), None, 'Gearbox', None, 2),
#  (839, 2022, 1095, 'Brazilian Grand Prix', 'Esteban Ocon', 8, Decimal('86'), None, 'Alpine F1 Team', 4, Decimal('167'), None, 'Finished', None, 2),
#  (4, 2022, 1095, 'Brazilian Grand Prix', 'Fernando Alonso', 9, Decimal('81'), None, 'Alpine F1 Team', 4, Decimal('167'), None, 'Finished', None, 3),
#  (822, 2022, 1095, 'Brazilian Grand Prix', 'Valtteri Bottas', 10, Decimal('49'), None, 'Alfa Romeo', 6, Decimal('55'), None, 'Finished', None, 2),
#  (20, 2022, 1095, 'Brazilian Grand Prix', 'Sebastian Vettel', 11, Decimal('36'), None, 'Aston Martin', 7, Decimal('50'), None, 'Finished', None, 2),
#  (817, 2022, 1095, 'Brazilian Grand Prix', 'Daniel Ricciardo', 12, Decimal('35'), None, 'McLaren', 5, Decimal('148'), None, 'Collision', None, None),
#  (825, 2022, 1095, 'Brazilian Grand Prix', 'Kevin Magnussen', 13, Decimal('25'), None, 'Haas F1 Team', 8, Decimal('37'), None, 'Collision', None, None),
#  (842, 2022, 1095, 'Brazilian Grand Prix', 'Pierre Gasly', 14, Decimal('23'), None, 'AlphaTauri', 9, Decimal('35'), None, 'Finished', None, 3),
#  (840, 2022, 1095, 'Brazilian Grand Prix', 'Lance Stroll', 15, Decimal('14'), None, 'Aston Martin', 7, Decimal('50'), None, 'Finished', None, 2),
#  (854, 2022, 1095, 'Brazilian Grand Prix', 'Mick Schumacher', 16, Decimal('12'), None, 'Haas F1 Team', 8, Decimal('37'), None, 'Finished', None, 2),
#  (852, 2022, 1095, 'Brazilian Grand Prix', 'Yuki Tsunoda', 17, Decimal('12'), None, 'AlphaTauri', 9, Decimal('35'), None, '+1 Lap', None, 3),
#  (855, 2022, 1095, 'Brazilian Grand Prix', 'Guanyu Zhou', 18, Decimal('6'), None, 'Alfa Romeo', 6, Decimal('55'), None, 'Finished', None, 2),
#  (848, 2022, 1095, 'Brazilian Grand Prix', 'Alexander Albon', 19, Decimal('4'), None, 'Williams', 10, Decimal('8'), None, 'Finished', None, 3),
#  (849, 2022, 1095, 'Brazilian Grand Prix', 'Nicholas Latifi', 20, Decimal('2'), None, 'Williams', 10, Decimal('8'), None, 'Finished', None, 3),
#  (830, 2022, 1096, 'Abu Dhabi Grand Prix', 'Max Verstappen', 1, Decimal('454'), 'Winner', 'Red Bull', 1, Decimal('759'), 'Team Winner', 'Finished', None, 1),
#  (844, 2022, 1096, 'Abu Dhabi Grand Prix', 'Charles Leclerc', 2, Decimal('308'), None, 'Ferrari', 2, Decimal('554'), None, 'Finished', None, 1),
#  (815, 2022, 1096, 'Abu Dhabi Grand Prix', 'Sergio Pérez', 3, Decimal('305'), None, 'Red Bull', 1, Decimal('759'), 'Team Winner', 'Finished', None, 2),
#  (847, 2022, 1096, 'Abu Dhabi Grand Prix', 'George Russell', 4, Decimal('275'), None, 'Mercedes', 3, Decimal('515'), None, 'Finished', None, 2),
#  (832, 2022, 1096, 'Abu Dhabi Grand Prix', 'Carlos Sainz', 5, Decimal('246'), None, 'Ferrari', 2, Decimal('554'), None, 'Finished', None, 2),
#  (1, 2022, 1096, 'Abu Dhabi Grand Prix', 'Lewis Hamilton', 6, Decimal('240'), None, 'Mercedes', 3, Decimal('515'), None, 'Hydraulics', None, 1),
#  (846, 2022, 1096, 'Abu Dhabi Grand Prix', 'Lando Norris', 7, Decimal('122'), None, 'McLaren', 5, Decimal('159'), None, 'Finished', 'Fastest Lap', 2),
#  (839, 2022, 1096, 'Abu Dhabi Grand Prix', 'Esteban Ocon', 8, Decimal('92'), None, 'Alpine F1 Team', 4, Decimal('173'), None, 'Finished', None, 2),
#  (4, 2022, 1096, 'Abu Dhabi Grand Prix', 'Fernando Alonso', 9, Decimal('81'), None, 'Alpine F1 Team', 4, Decimal('173'), None, 'Water leak', None, 1),
#  (822, 2022, 1096, 'Abu Dhabi Grand Prix', 'Valtteri Bottas', 10, Decimal('49'), None, 'Alfa Romeo', 6, Decimal('55'), None, '+1 Lap', None, 1),
#  (817, 2022, 1096, 'Abu Dhabi Grand Prix', 'Daniel Ricciardo', 11, Decimal('37'), None, 'McLaren', 5, Decimal('159'), None, 'Finished', None, 1),
#  (20, 2022, 1096, 'Abu Dhabi Grand Prix', 'Sebastian Vettel', 12, Decimal('37'), None, 'Aston Martin', 7, Decimal('55'), None, 'Finished', None, 1),
#  (825, 2022, 1096, 'Abu Dhabi Grand Prix', 'Kevin Magnussen', 13, Decimal('25'), None, 'Haas F1 Team', 8, Decimal('37'), None, '+1 Lap', None, 1),
#  (842, 2022, 1096, 'Abu Dhabi Grand Prix', 'Pierre Gasly', 14, Decimal('23'), None, 'AlphaTauri', 9, Decimal('35'), None, '+1 Lap', None, 1),
#  (840, 2022, 1096, 'Abu Dhabi Grand Prix', 'Lance Stroll', 15, Decimal('18'), None, 'Aston Martin', 7, Decimal('55'), None, 'Finished', None, 2),
#  (854, 2022, 1096, 'Abu Dhabi Grand Prix', 'Mick Schumacher', 16, Decimal('12'), None, 'Haas F1 Team', 8, Decimal('37'), None, '+1 Lap', None, 2),
#  (852, 2022, 1096, 'Abu Dhabi Grand Prix', 'Yuki Tsunoda', 17, Decimal('12'), None, 'AlphaTauri', 9, Decimal('35'), None, 'Finished', None, 2),
#  (855, 2022, 1096, 'Abu Dhabi Grand Prix', 'Guanyu Zhou', 18, Decimal('6'), None, 'Alfa Romeo', 6, Decimal('55'), None, '+1 Lap', None, 2),
#  (848, 2022, 1096, 'Abu Dhabi Grand Prix', 'Alexander Albon', 19, Decimal('4'), None, 'Williams', 10, Decimal('8'), None, '+1 Lap', None, 2),
#  (849, 2022, 1096, 'Abu Dhabi Grand Prix', 'Nicholas Latifi', 20, Decimal('2'), None, 'Williams', 10, Decimal('8'), None, 'Collision damage', None, 2)]

# %% [markdown]
# ## 9. List down the names of all F1 champions and the no of times they have won it.

# %%
# %%sql
# with no_champs as -- Temp table of the number of times drivers have won F1 championships.
# 	(
# 	select driverid, count(1) as no_champs
# 	from
# 		(
# 		select year, driverid, sum(points) as tot_points,
# 		dense_rank() over(partition by year order by sum(points) desc) as rk
# 		from results res
# 		join races r on res.raceid = r.raceid
# 		group by 1,2
# 		order by 4, 1
# 		)x -- Subquery to find out the total points that every driver earns in each year
# 	where rk = 1
# 	group by 1
# 	)
# select concat(forename, ' ', surname) as driver, no_champs
# from drivers d
# join no_champs c on d.driverid = c.driverid
# order by 2 desc
# limit 5;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 5 rows affected.
# [('Michael Schumacher', 7),
#  ('Lewis Hamilton', 7),
#  ('Alain Prost', 5),
#  ('Juan Fangio', 5),
#  ('Sebastian Vettel', 4)]

# %% [markdown]
# ## 10. Who has won the most constructor championships

# %%
# %%sql
# with no_champs as -- Temp talbe of how many time a team won championship of all time
# 	(
# 	select constructorid, count(1) as no_champs
# 	from
# 		(
# 		select year, constructorid, sum(points) as tot_points
# 		,dense_rank() over(partition by year order by sum(points) desc) as rk
# 		from constructor_results cs
# 		join races r on cs.raceid = r.raceid
# 		group by 1,2
# 		order by 4,1
# 		)x -- Subquery to rank the total points earned by a team in a year from highest to lowest.
# 	where rk = 1
# 	group by 1
# 	order by 2
# 	)
# select name, no_champs
# from constructors c
# join no_champs chm on c.constructorid = chm.constructorid
# order by 2 desc
# limit 5;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 5 rows affected.
# [('Ferrari', 15),
#  ('McLaren', 9),
#  ('Williams', 9),
#  ('Mercedes', 8),
#  ('Red Bull', 5)]

# %% [markdown]
# ## 11. How many races has India hosted?

# %%
# %%sql
# select c.name as circuit_name, c.country, count(1) as no_races
# from races r
# join circuits c on r.circuitid = c.circuitid
# where country = 'India'
# group by 1,2;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 1 rows affected.
# [('Buddh International Circuit', 'India', 3)]

# %% [markdown]
# ## 12. Identify the driver who won the championship or was a runner-up. Also display the team they belonged to. After year 2019

# %%
# %%sql
# with first_second as -- Temp table to flag out winnder and runner-up
# 	(
# 	select *,
# 		case when rk = 1 then 'Winner' else 'Runner-up' end as flag
# 	from
# 		(
# 		select year, driverid, constructorid, sum(points) as tot_points,
# 		dense_rank() over(partition by year order by sum(points) desc) as rk
# 		from results re
# 		join races r on re.raceid = r.raceid
# 		group by 1, 2, 3
# 		order by 1, 4 desc
# 		) x -- Subquery to rank total points earn by drivers in a year from highest to lowest.
# 	where rk <=2
# 	)
#
# select year, concat(forename, ' ', surname) as driver, c.name as team, flag
# from first_second f
# join constructors c on f.constructorid = c.constructorid
# join drivers d on f.driverid = d.driverid
# where year >= 2020;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 7 rows affected.
# [(2020, 'Lewis Hamilton', 'Mercedes', 'Winner'),
#  (2020, 'Valtteri Bottas', 'Mercedes', 'Runner-up'),
#  (2021, 'Max Verstappen', 'Red Bull', 'Winner'),
#  (2021, 'Lewis Hamilton', 'Mercedes', 'Runner-up'),
#  (2022, 'Max Verstappen', 'Red Bull', 'Winner'),
#  (2022, 'Sergio Pérez', 'Red Bull', 'Runner-up'),
#  (2022, 'Charles Leclerc', 'Ferrari', 'Runner-up')]

# %% [markdown]
# ## 13. Display the top 10 drivers with most wins.

# %%
# %%sql
# with top_rank as -- Temp table to rank the total wins earned by driver from highest to lowest.
# 	(
# 	select driverid, count(1) as no_wins,
# 	dense_rank() over(order by sum(wins) desc) as rk
# 	from driver_standings
# 	where position = 1
# 	group by 1
# 	order by 2 desc
# 	)
# select concat(forename,' ',surname) as driver, no_wins
# from top_rank rk
# join drivers d on rk.driverid = d.driverid
# where rk <=10
# order by 2 desc;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 10 rows affected.
# [('Lewis Hamilton', 125),
#  ('Michael Schumacher', 121),
#  ('Alain Prost', 79),
#  ('Sebastian Vettel', 63),
#  ('Fernando Alonso', 52),
#  ('Ayrton Senna', 48),
#  ('Niki Lauda', 42),
#  ('Max Verstappen', 32),
#  ('Nico Rosberg', 29),
#  ('Nigel Mansell', 25)]

# %% [markdown]
# ## 14. Display the top 3 constructors of all time.

# %%
# %%sql
# select name as team_name, no_wins
# 	from (
# 	select cs.constructorid, c.name, count(1) as no_wins,
# 	dense_rank() over(order by count(1) desc) rk
# 	from constructor_standings cs
# 	join constructors c on cs.constructorid = c.constructorid
# 	where position = 1
# 	group by 1,2
# 	) x --subquery to rank total wins races by team from highest to lowest
# where rk < 4
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 3 rows affected.
# [('Ferrari', 234), ('McLaren', 165), ('Mercedes', 145)]

# %% [markdown]
# ## 15. Identify the drivers who have won races with multiple teams.

# %%
# %%sql
# with temp as -- Temp table to get a drivers who won races with multiple teams.
# 			(
# 			select driverid, count(1) as no_team, string_agg(name, ',') as teams
# 			from(
# 			select distinct driverid, c.name
# 			from results r
# 			join constructors c on r.constructorid = c.constructorid
# 			where position = 1
# 			order by 1
# 			)x -- Subquery to retrieve all the teams that have won the race.
# 			group by 1
# 			)
# select d.driverid, concat(forename,' ', surname) as driver_name, no_team, teams
# from drivers d
# join temp t on d.driverid = t.driverid
# where no_team > 1
# order by 1
# limit 10; -- Avoid for long output
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 52 rows affected.
# [(1, 'Lewis Hamilton', 2, 'McLaren,Mercedes'),
#  (4, 'Fernando Alonso', 3, 'Ferrari,McLaren,Renault'),
#  (8, 'Kimi Räikkönen', 3, 'Ferrari,Lotus F1,McLaren'),
#  (14, 'David Coulthard', 2, 'McLaren,Williams'),
#  (18, 'Jenson Button', 3, 'Brawn,Honda,McLaren'),
#  (20, 'Sebastian Vettel', 3, 'Ferrari,Red Bull,Toro Rosso'),
#  (21, 'Giancarlo Fisichella', 2, 'Jordan,Renault'),
#  (22, 'Rubens Barrichello', 2, 'Brawn,Ferrari'),
#  (30, 'Michael Schumacher', 2, 'Benetton,Ferrari'),
#  (31, 'Juan Pablo Montoya', 2, 'McLaren,Williams'),
#  (49, 'Heinz-Harald Frentzen', 2, 'Jordan,Williams'),
#  (65, 'Johnny Herbert', 2, 'Benetton,Stewart'),
#  (71, 'Damon Hill', 2, 'Jordan,Williams'),
#  (77, 'Gerhard Berger', 3, 'Benetton,Ferrari,McLaren'),
#  (95, 'Nigel Mansell', 2, 'Ferrari,Williams'),
#  (102, 'Ayrton Senna', 2, 'McLaren,Team Lotus'),
#  (105, 'Michele Alboreto', 2, 'Ferrari,Tyrrell'),
#  (117, 'Alain Prost', 4, 'Ferrari,McLaren,Renault,Williams'),
#  (119, 'Riccardo Patrese', 2, 'Brabham,Williams'),
#  (137, 'Nelson Piquet', 3, 'Benetton,Brabham,Williams'),
#  (163, 'René Arnoux', 2, 'Ferrari,Renault'),
#  (178, 'Alan Jones', 2, 'Shadow,Williams'),
#  (182, 'Niki Lauda', 3, 'Brabham,Ferrari,McLaren'),
#  (187, 'John Watson', 2, 'McLaren,Penske'),
#  (199, 'Carlos Reutemann', 3, 'Brabham,Ferrari,Williams'),
#  (202, 'Didier Pironi', 2, 'Ferrari,Ligier'),
#  (207, 'Mario Andretti', 2, 'Ferrari,Team Lotus'),
#  (221, 'Patrick Depailler', 2, 'Ligier,Tyrrell'),
#  (222, 'Jody Scheckter', 3, 'Ferrari,Tyrrell,Wolf'),
#  (223, 'Clay Regazzoni', 2, 'Ferrari,Williams'),
#  (224, 'Emerson Fittipaldi', 2, 'McLaren,Team Lotus'),
#  (231, 'James Hunt', 2, 'Hesketh,McLaren'),
#  (235, 'Jacky Ickx', 2, 'Brabham-Ford,Ferrari'),
#  (238, 'Ronnie Peterson', 2, 'March,Team Lotus'),
#  (289, 'Graham Hill', 2, 'BRM,Lotus-Ford'),
#  (304, 'Denny Hulme', 3, 'Brabham-Repco,McLaren,McLaren-Ford'),
#  (328, 'Jackie Stewart', 4, 'BRM,March,Matra-Ford,Tyrrell'),
#  (341, 'John Surtees', 3, 'Cooper-Maserati,Ferrari,Honda'),
#  (345, 'Pedro Rodríguez', 2, 'BRM,Cooper-Maserati'),
#  (346, 'Jo Siffert', 2, 'BRM,Lotus-Ford'),
#  (356, 'Jack Brabham', 3, 'Brabham,Brabham-Repco,Cooper-Climax'),
#  (358, 'Jochen Rindt', 2, 'Lotus-Ford,Team Lotus'),
#  (360, 'Bruce McLaren', 2, 'Cooper-Climax,McLaren-Ford'),
#  (364, 'Dan Gurney', 3, 'Brabham-Climax,Eagle-Weslake,Porsche'),
#  (373, 'Jim Clark', 3, 'Lotus-BRM,Lotus-Climax,Lotus-Ford'),
#  (427, 'Maurice Trintignant', 2, 'Cooper,Ferrari'),
#  (475, 'Stirling Moss', 7, 'Cooper,Cooper-Climax,Lotus-Climax,Maserati,Mercedes,Team Lotus,Vanwall'),
#  (479, 'Tony Brooks', 2, 'Ferrari,Vanwall'),
#  (579, 'Juan Fangio', 4, 'Alfa Romeo,Ferrari,Maserati,Mercedes'),
#  (642, 'Nino Farina', 2, 'Alfa Romeo,Ferrari'),
#  (815, 'Sergio Pérez', 2, 'Racing Point,Red Bull'),
#  (817, 'Daniel Ricciardo', 2, 'McLaren,Red Bull')]

# %% [markdown]
# ## 16. How many drivers have never won any race.

# %%
# %%sql
# select distinct(driverid) , concat(forename,' ',surname) as driver_name ,nationality
# from drivers
# where driverid not in (
# 					select distinct driverid
# 					from driver_standings
# 					where position = 1
# 					  ) -- Subquery of all drivers who have won races.
# order by 2
# limit 10; -- Avoid for long output
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 794 rows affected.
# [(750, 'Adolf Brudes', 'German'),
#  (698, 'Adolfo Cruz', 'Argentine'),
#  (16, 'Adrian Sutil', 'German'),
#  (167, 'Adrián Campos', 'Spanish'),
#  (88, 'Aguri Suzuki', 'Japanese'),
#  (538, 'Al Herman', 'American'),
#  (558, 'Al Keller', 'American'),
#  (371, 'Al Pease', 'Canadian'),
#  (550, 'Alain de Changy', 'Belgian'),
#  (689, 'Alan Brown', 'British'),
#  (390, 'Alan Rees', 'British'),
#  (421, 'Alan Rollinson', 'British'),
#  (502, 'Alan Stacey', 'British'),
#  (719, 'Albert Scherrer', 'Swiss'),
#  (244, 'Alberto Colombo', 'Italian'),
#  (761, 'Alberto Crespo', 'Argentine'),
#  (497, 'Alberto Rodriguez Larreta', 'Argentine'),
#  (623, 'Alberto Uria', 'Uruguayan'),
#  (775, 'Aldo Gordini', 'French'),
#  (145, 'Alessandro Nannini', 'Italian'),
#  (284, 'Alessandro Pesenti-Rossi', 'Italian'),
#  (70, 'Alessandro Zanardi', 'Italian'),
#  (573, 'Alessandro de Tomaso', 'Argentine-Italian'),
#  (417, 'Alex Blignaut', 'South African'),
#  (133, 'Alex Caffi', 'Italian'),
#  (237, 'Alex Ribeiro', 'Brazilian'),
#  (339, 'Alex Soler-Roig', 'Spanish'),
#  (62, 'Alex Yoong', 'Malaysian'),
#  (834, 'Alexander Rossi', 'American'),
#  (25, 'Alexander Wurz', 'Austrian'),
#  (491, 'Alfonso Thiele', 'American-Italian'),
#  (606, 'Alfonso de Portago', 'Spanish'),
#  (792, 'Alfredo Pián', 'Argentine'),
#  (66, 'Allan McNish', 'British'),
#  (180, 'Allen Berg', 'Canadian'),
#  (130, 'Andrea Chiesa', 'Swiss'),
#  (85, 'Andrea Montermini', 'Italian'),
#  (333, 'Andrea de Adamich', 'Italian'),
#  (110, 'Andrea de Cesaris', 'Italian'),
#  (603, 'André Guelfi', 'French'),
#  (827, 'André Lotterer', 'German'),
#  (639, 'André Milhoux', 'Belgian'),
#  (429, 'André Pilette', 'Belgian'),
#  (609, 'André Simon', 'French'),
#  (553, 'André Testut', 'Monegasque'),
#  (612, 'Andy Linden', 'American'),
#  (264, 'Andy Sutcliffe', 'British'),
#  (19, 'Anthony Davidson', 'British'),
#  (531, 'Anthony Foyt', 'American'),
#  (504, 'Antonio Creus', 'Spanish'),
#  (841, 'Antonio Giovinazzi', 'Italian'),
#  (42, 'Antônio Pizzonia', 'Brazilian'),
#  (637, 'Archie Scott Brown', 'British'),
#  (599, 'Art Bisch', 'American'),
#  (656, 'Art Cross', 'American'),
#  (703, 'Arthur Legat', 'Belgian'),
#  (546, 'Arthur Owen', 'British'),
#  (232, 'Arturo Merzario', 'Italian'),
#  (568, 'Azdrubal Fontes', 'Uruguayan'),
#  (369, 'Basil van Rooyen', 'South African'),
#  (798, 'Bayliss Levrett', 'American'),
#  (457, 'Ben Pon', 'Dutch'),
#  (213, 'Beppe Gabbiani', 'Italian'),
#  (428, 'Bernard Collomb', 'French'),
#  (261, 'Bernard de Dryver', 'Belgian'),
#  (146, 'Bernd Schneider', 'German'),
#  (587, 'Bernie Ecclestone', 'British'),
#  (318, 'Bertil Roos', 'Swedish'),
#  (92, 'Bertrand Gachot', 'Belgian'),
#  (749, 'Bill Aston', 'British'),
#  (343, 'Bill Brack', 'Canadian'),
#  (803, 'Bill Cantrell', 'American'),
#  (560, 'Bill Cheesbourg', 'American'),
#  (701, 'Bill Holland', 'American'),
#  (519, 'Bill Homeier', 'American'),
#  (769, 'Bill Mackey', 'American'),
#  (570, 'Bill Moss', 'British'),
#  (729, 'Bill Schindler', 'American'),
#  (657, 'Bill Vukovich', 'American'),
#  (684, 'Bill Whitehouse', 'British'),
#  (595, 'Billy Garrett', 'American'),
#  (383, 'Bob Anderson', 'British'),
#  (396, 'Bob Bondurant', 'American'),
#  (516, 'Bob Christie', 'American'),
#  (548, 'Bob Drake', 'American'),
#  (276, 'Bob Evans', 'British'),
#  (619, 'Bob Gerard', 'British'),
#  (575, 'Bob Said', 'American'),
#  (702, 'Bob Scott', 'American'),
#  (628, 'Bob Sweikert', 'American'),
#  (514, 'Bob Veith', 'American'),
#  (734, 'Bobby Ball', 'American'),
#  (522, 'Bobby Grim', 'American'),
#  (249, 'Bobby Rahal', 'American'),
#  (381, 'Bobby Unser', 'American'),
#  (257, 'Boy Lunger', 'Dutch'),
#  (412, 'Brausch Niemann', 'South African'),
#  (843, 'Brendon Hartley', 'New Zealander'),
#  (239, 'Brett Lunger', 'American'),
#  (422, 'Brian Gubby', 'British'),
#  (391, 'Brian Hart', 'British'),
#  (205, 'Brian Henton', 'British'),
#  (266, 'Brian McGuire', 'Australian'),
#  (484, 'Brian Naylor', 'British'),
#  (312, 'Brian Redman', 'British'),
#  (778, 'Brian Shawe Taylor', 'British'),
#  (506, 'Bruce Halford', 'British'),
#  (471, 'Bruce Johnstone', 'South African'),
#  (584, 'Bruce Kessler', 'American'),
#  (152, 'Bruno Giacomelli', 'Italian'),
#  (811, 'Bruno Senna', 'Brazilian'),
#  (515, 'Bud Tingelstad', 'American'),
#  (655, 'Cal Niday', 'American'),
#  (430, 'Carel Godin de Beaufort', 'Dutch'),
#  (767, 'Carl Forberg', 'American'),
#  (700, 'Carl Scarborough', 'American'),
#  (446, 'Carlo Abate', 'Italian'),
#  (325, 'Carlo Facetti', 'Italian'),
#  (248, 'Carlo Franchi', 'Italian'),
#  (496, 'Carlos Menditeguy', 'Argentine'),
#  (250, 'Carlos Pace', 'Brazilian'),
#  (832, 'Carlos Sainz', 'Spanish'),
#  (566, 'Carroll Shelby', 'American'),
#  (770, 'Cecil Green', 'American'),
#  (607, 'Cesare Perdisa', 'Italian'),
#  (819, 'Charles Pic', 'French'),
#  (801, 'Charles Pozzi', 'French'),
#  (735, 'Charles de Tornaco', 'Belgian'),
#  (733, 'Chet Miller', 'American'),
#  (622, 'Chico Landi', 'Brazilian'),
#  (192, 'Chico Serra', 'Brazilian'),
#  (278, 'Chris Amon', 'New Zealander'),
#  (505, 'Chris Bristow', 'British'),
#  (354, 'Chris Craft', 'British'),
#  (388, 'Chris Irwin', 'British'),
#  (400, 'Chris Lawrence', 'British'),
#  (157, 'Christian Danner', 'German'),
#  (104, 'Christian Fittipaldi', 'Brazilian'),
#  (600, 'Christian Goethals', 'Belgian'),
#  (32, 'Christian Klien', 'Austrian'),
#  (27, 'Christijan Albers', 'Dutch'),
#  (557, 'Chuck Arnold', 'American'),
#  (507, 'Chuck Daigh', 'American'),
#  (521, 'Chuck Stevenson', 'American'),
#  (563, 'Chuck Weyant', 'American'),
#  (149, 'Claudio Langes', 'Italian'),
#  (645, 'Clemar Bucci', 'Argentine'),
#  (791, 'Clemente Biondetti', 'Italian'),
#  (477, 'Cliff Allison', 'British'),
#  (629, 'Cliff Griffith', 'American'),
#  (414, 'Clive Puzey', 'Rhodesian'),
#  (635, 'Colin Chapman', 'British'),
#  (462, 'Colin Davis', 'British'),
#  (260, 'Conny Andersson', 'Swedish'),
#  (763, 'Consalvo Sanesi', 'Italian'),
#  (190, 'Corrado Fabi', 'Italian'),
#  (43, 'Cristiano da Matta', 'Brazilian'),
#  (787, 'Cuth Harrison', 'British'),
#  (282, 'Damien Magee', 'British'),
#  (364, 'Dan Gurney', 'American'),
#  (817, 'Daniel Ricciardo', 'Australian'),
#  (826, 'Daniil Kvyat', 'Russian'),
#  (805, 'Danny Kladis', 'American'),
#  (240, 'Danny Ongais', 'American'),
#  (193, 'Danny Sullivan', 'American'),
#  (293, 'Dave Charlton', 'South African'),
#  (225, 'Dave Kennedy', 'Irish'),
#  (301, 'Dave Morgan', 'British'),
#  (101, 'David Brabham', 'Australian'),
#  (416, 'David Clapham', 'South African'),
#  (784, 'David Hampshire', 'British'),
#  (322, 'David Hobbs', 'British'),
#  (747, 'David Murray', 'British'),
#  (542, 'David Piper', 'British'),
#  (407, 'David Prophet', 'British'),
#  (259, 'David Purley', 'British'),
#  (338, 'David Walker', 'Australian'),
#  (539, 'Dempsey Wilson', 'American'),
#  (742, 'Dennis Poore', 'British'),
#  (571, 'Dennis Taylor', 'British'),
#  (321, 'Derek Bell', 'British'),
#  (206, 'Derek Daly', 'Irish'),
#  (118, 'Derek Warwick', 'British'),
#  (228, 'Desiré Wilson', 'South African'),
#  (636, 'Desmond Titterington', 'British'),
#  (601, 'Dick Gibson', 'British'),
#  (537, 'Dick Rathmann', 'American'),
#  (323, 'Dieter Quester', 'Austrian'),
#  (242, 'Divina Galica', 'British'),
#  (93, 'Domenico Schiattarella', 'Italian'),
#  (682, 'Don Beauman', 'British'),
#  (511, 'Don Branson', 'American'),
#  (614, 'Don Edmunds', 'American'),
#  (528, 'Don Freeland', 'American'),
#  (802, 'Dorino Serafini', 'Italian'),
#  (411, 'Doug Serrurier', 'South African'),
#  (758, 'Dries van der Lof', 'Dutch'),
#  (518, 'Duane Carter', 'American'),
#  (630, 'Duke Dinsmore', 'American'),
#  (699, 'Duke Nalon', 'American'),
#  (708, 'Duncan Hamilton', 'British'),
#  (596, 'Ed Elisian', 'American'),
#  (158, 'Eddie Cheever', 'American'),
#  (513, 'Eddie Johnson', 'American'),
#  (292, 'Eddie Keizan', 'South African'),
#  (532, 'Eddie Russo', 'American'),
#  (527, 'Eddie Sachs', 'American'),
#  (431, 'Edgar Barth', 'German'),
#  (748, 'Eitel Cantoni', 'Uruguayan'),
#  (194, 'Eliseo Salazar', 'Chilean'),
#  (616, 'Elmer George', 'American'),
#  (125, 'Emanuele Naspetti', 'Italian'),
#  (139, 'Emanuele Pirro', 'Italian'),
#  (279, 'Emilio Zapico', 'Spanish'),
#  (208, 'Emilio de Villota', 'Spanish'),
#  (134, 'Enrico Bertaggia', 'Italian'),
#  (59, 'Enrique Bernoldi', 'Brazilian'),
#  (326, 'Eppie Wietzes', 'Canadian'),
#  (688, 'Eric Brandon', 'British'),
#  (743, 'Eric Thompson', 'British'),
#  (128, 'Eric van de Poele', 'Belgian'),
#  (443, 'Ernesto Brambilla', 'Italian'),
#  (467, 'Ernesto Prinoth', 'Italian'),
#  (679, 'Ernie McCoy', 'American'),
#  (413, 'Ernie Pieterse', 'South African'),
#  (450, 'Ernie de Vos', 'Dutch'),
#  (709, 'Ernst Klodwig', 'East German'),
#  (718, 'Ernst Loof', 'German'),
#  (716, 'Erwin Bauer', 'German'),
#  (821, 'Esteban Gutiérrez', 'Mexican'),
#  (839, 'Esteban Ocon', 'French'),
#  (74, 'Esteban Tuero', 'Argentine'),
#  (503, 'Ettore Chimeri', 'Venezuelan'),
#  (608, 'Eugenio Castellotti', 'Italian'),
#  (774, 'Eugène Chaboud', 'French'),
#  (789, 'Eugène Martin', 'French'),
#  (120, 'Fabrizio Barbazza', 'Italian'),
#  (697, 'Felice Bonetto', 'Italian'),
#  (831, 'Felipe Nasr', 'Brazilian'),
#  (116, 'Franck Lagorce', 'French'),
#  (36, 'Franck Montagny', 'French'),
#  (740, 'Franco Comotti', 'Italian'),
#  (171, 'Franco Forini', 'Swiss'),
#  (762, 'Franco Rol', 'Italian'),
#  (676, 'Frank Armi', 'American'),
#  (451, 'Frank Dochnal', 'American'),
#  (380, 'Frank Gardner', 'Australian'),
#  (327, 'François Cevert', 'French'),
#  (183, 'François Hesnault', 'French'),
#  (348, 'François Mazet', 'French'),
#  (296, 'François Migault', 'French'),
#  (604, 'François Picard', 'French'),
#  (615, 'Fred Agabashian', 'American'),
#  (545, 'Fred Gamble', 'American'),
#  (693, 'Fred Wacker', 'American'),
#  (751, 'Fritz Riess', 'German'),
#  (567, "Fritz d'Orey", 'Brazilian'),
#  (99, 'Gabriele Tarquini', 'Italian'),
#  (447, 'Gaetano Starrabba', 'Italian'),
#  (150, 'Gary Brabham', 'Australian'),
#  (473, 'Gary Hocking', 'Rhodesian'),
#  (60, 'Gastón Mazzacane', 'Argentine'),
#  (534, 'Gene Force', 'American'),
#  (520, 'Gene Hartley', 'American'),
#  (785, 'Geoff Crossley', 'British'),
#  (490, 'Geoff Duke', 'British'),
#  (209, 'Geoff Lees', 'British'),
#  (725, 'George Abecassis', 'British'),
#  (591, 'George Amick', 'American'),
#  (726, 'George Connor', 'American'),
#  (574, 'George Constantine', 'American'),
#  (352, 'George Eaton', 'Canadian'),
#  (332, 'George Follmer', 'American'),
#  (730, 'George Fonder', 'American'),
#  (847, 'George Russell', 'British'),
#  (681, 'Georges Berger', 'Belgian'),
#  (783, 'Georges Grignard', 'French'),
#  (77, 'Gerhard Berger', 'Austrian'),
#  (423, 'Gerhard Mitter', 'German'),
#  (583, 'Gerino Gerini', 'Italian'),
#  (460, 'Gerry Ashmore', 'British'),
#  (402, 'Giacomo Russo', 'Italian'),
#  (394, 'Giancarlo Baghetti', 'Italian'),
#  (234, 'Gianfranco Brancatelli', 'Italian'),
#  (46, 'Gianmaria Bruni', 'Italian'),
#  (81, 'Gianni Morbidelli', 'Italian'),
#  (823, 'Giedo van der Garde', 'Dutch'),
#  (298, 'Gijs van Lennep', 'Dutch'),
#  (746, 'Gino Bianco', 'Brazilian'),
#  (500, 'Gino Munaron', 'Italian'),
#  (426, 'Giorgio Bassi', 'Italian'),
#  (220, 'Giorgio Francia', 'Italian'),
#  (45, 'Giorgio Pantano', 'Italian'),
#  (483, 'Giorgio Scarlatti', 'Italian'),
#  (132, 'Giovanna Amati', 'Italian'),
#  (86, 'Giovanni Lavaggi', 'Italian'),
#  (694, 'Giovanni de Riu', 'Italian'),
#  (543, 'Giulio Cabianca', 'Italian'),
#  (336, 'Graham McRae', 'New Zealander'),
#  (745, 'Graham Whitehead', 'British'),
#  (148, 'Gregor Foitek', 'Swiss'),
#  (855, 'Guanyu Zhou', 'Chinese'),
#  (255, 'Gunnar Nilsson', 'Swedish'),
#  (366, 'Gus Hutchison', 'American'),
#  (265, 'Guy Edwards', 'British'),
#  (389, 'Guy Ligier', 'French'),
#  (764, 'Guy Mairesse', 'French'),
#  (291, 'Guy Tunmer', 'South African'),
#  (315, 'Gérard Larrousse', 'French'),
#  (715, 'Günther Bechem', 'German'),
#  (445, 'Günther Seiffert', 'German'),
#  (246, 'Hans Binder', 'Austrian'),
#  (478, 'Hans Herrmann', 'German'),
#  (268, 'Hans Heyer', 'German'),
#  (753, 'Hans Klenk', 'German'),
#  (717, 'Hans von Stuck', 'German'),
#  (233, 'Hans-Joachim Stuck', 'German'),
#  (434, 'Hap Sharp', 'American'),
#  (229, 'Harald Ertl', 'Austrian'),
#  (572, 'Harry Blanchard', 'American'),
#  (501, 'Harry Schell', 'American'),
#  (212, 'Hector Rebaque', 'Mexican'),
#  (5, 'Heikki Kovalainen', 'Finnish'),
#  (466, 'Heini Walter', 'Swiss'),
#  (461, 'Heinz Schiller', 'Swiss'),
#  (49, 'Heinz-Harald Frentzen', 'German'),
#  (337, 'Helmut Marko', 'Austrian'),
#  (752, 'Helmut Niedermayr', 'German'),
#  (324, 'Helmuth Koinigg', 'Austrian'),
#  (765, 'Henri Louveau', 'French'),
#  (280, 'Henri Pescarolo', 'French'),
#  (731, 'Henry Banks', 'American'),
#  (481, 'Henry Taylor', 'British'),
#  (618, 'Herbert MacKay-Fraser', 'American'),
#  (691, 'Hermann Lang', 'German'),
#  (624, 'Hernando da Silva Ramos', 'Brazilian'),
#  (115, 'Hideki Noda', 'Japanese'),
#  (299, 'Hiroshi Fushida', 'Japanese'),
#  (547, 'Horace Gould', 'British'),
#  (307, 'Howden Ganley', 'New Zealander'),
#  (365, 'Hubert Hahne', 'German'),
#  (179, 'Huub Rothengatter', 'Dutch'),
#  (270, 'Ian Ashley', 'British'),
#  (437, 'Ian Burgess', 'British'),
#  (420, 'Ian Raby', 'British'),
#  (251, 'Ian Scheckter', 'South African'),
#  (707, 'Ian Stewart', 'British'),
#  (363, 'Ignazio Giunti', 'Italian'),
#  (253, 'Ingo Hoffmann', 'Brazilian'),
#  (404, 'Innes Ireland', 'British'),
#  (122, 'Ivan Capelli', 'Italian'),
#  (549, 'Ivor Bueb', 'British'),
#  (281, 'Jac Nelleman', 'Danish'),
#  (851, 'Jack Aitken', 'British'),
#  (486, 'Jack Fairman', 'British'),
#  (658, 'Jack McGrath', 'American'),
#  (562, 'Jack Turner', 'American'),
#  (797, 'Jackie Holmes', 'American'),
#  (453, 'Jackie Lewis', 'British'),
#  (262, 'Jackie Oliver', 'British'),
#  (334, 'Jackie Pretorius', 'South African'),
#  (235, 'Jacky Ickx', 'Belgian'),
#  (650, 'Jacques Pollet', 'French'),
#  (680, 'Jacques Swaters', 'American'),
#  (198, 'Jacques Villeneuve Sr.', 'Canadian'),
#  (153, 'Jaime Alguersuari', 'Spanish'),
#  (759, 'Jan Flinterman', 'Dutch'),
#  (136, 'Jan Lammers', 'Dutch'),
#  (76, 'Jan Magnussen', 'Danish'),
#  (15, 'Jarno Trulli', 'Italian'),
#  (463, 'Jay Chamberlain', 'American'),
#  (55, 'Jean Alesi', 'French'),
#  (668, 'Jean Lucas', 'French'),
#  (552, 'Jean Lucienbonnet', 'French'),
#  (96, 'Jean-Christophe Boullion', 'French'),
#  (98, 'Jean-Denis Délétraz', 'Swiss'),
#  (168, 'Jean-Louis Schlesser', 'French'),
#  (111, 'Jean-Marc Gounon', 'French'),
#  (306, 'Jean-Pierre Beltoise', 'French'),
#  (219, 'Jean-Pierre Jabouille', 'French'),
#  (197, 'Jean-Pierre Jarier', 'French'),
#  (818, 'Jean-Éric Vergne', 'French'),
#  (659, 'Jerry Hoyt', 'American'),
#  (598, 'Jerry Unser', 'American'),
#  (646, 'Jesús Iglesias', 'Argentine'),
#  (302, 'Jim Crawford', 'British'),
#  (440, 'Jim Hall', 'American'),
#  (524, 'Jim Hurtubise', 'American'),
#  (535, 'Jim McWithey', 'American'),
#  (509, 'Jim Rathmann', 'American'),
#  (727, 'Jim Rigsby', 'American'),
#  (525, 'Jimmy Bryan', 'American'),
#  (653, 'Jimmy Davies', 'American'),
#  (556, 'Jimmy Daywalt', 'American'),
#  (799, 'Jimmy Jackson', 'American'),
#  (592, 'Jimmy Reece', 'American'),
#  (706, 'Jimmy Stewart', 'British'),
#  (347, 'Jo Bonnier', 'Swedish'),
#  (189, 'Jo Gartner', 'Austrian'),
#  (377, 'Jo Schlesser', 'French'),
#  (346, 'Jo Siffert', 'Swiss'),
#  (303, 'Jo Vonlanthen', 'Swiss'),
#  (164, 'Joachim Winkelhock', 'German'),
#  (200, 'Jochen Mass', 'German'),
#  (788, 'Joe Fry', 'British'),
#  (728, 'Joe James', 'American'),
#  (776, 'Joe Kelly', 'Irish'),
#  (696, 'John Barber', 'British'),
#  (436, 'John Campbell-Jones', 'British'),
#  (355, 'John Cannon', 'Canadian'),
#  (372, 'John Cordts', 'Canadian'),
#  (667, 'John Fitch', 'American'),
#  (779, 'John James', 'British'),
#  (340, 'John Love', 'Rhodesian'),
#  (357, 'John Miles', 'British'),
#  (300, 'John Nicholson', 'New Zealander'),
#  (419, 'John Rhodes', 'British'),
#  (685, 'John Riseley-Prichard', 'British'),
#  (399, 'John Taylor', 'British'),
#  (593, 'Johnnie Parsons', 'American'),
#  (594, 'Johnnie Tolan', 'American'),
#  (533, 'Johnny Boyd', 'American'),
#  (188, 'Johnny Cecotto', 'Venezuelan'),
#  (660, 'Johnny Claes', 'Belgian'),
#  (174, 'Johnny Dumfries', 'British'),
#  (65, 'Johnny Herbert', 'British'),
#  (804, 'Johnny Mantz', 'American'),
#  (732, 'Johnny McDowell', 'American'),
#  (359, 'Johnny Servoz-Gavin', 'French'),
#  (512, 'Johnny Thomson', 'American'),
#  (794, 'Joie Chitwood', 'American'),
#  (835, 'Jolyon Palmer', 'British'),
#  (156, 'Jonathan Palmer', 'British'),
#  (395, 'Jonathan Williams', 'British'),
#  (672, 'Jorge Daponte', 'Argentine'),
#  (50, 'Jos Verstappen', 'Dutch'),
#  (757, 'Josef Peters', 'German'),
#  (319, 'José Dolhem', 'French'),
#  (498, 'José Froilán González', 'Argentine'),
#  (782, 'Juan Jover', 'Spanish'),
#  (485, 'Juan Manuel Bordeu', 'Argentine'),
#  (31, 'Juan Pablo Montoya', 'Colombian'),
#  (564, 'Jud Larson', 'American'),
#  (824, 'Jules Bianchi', 'French'),
#  (141, 'Julian Bailey', 'British'),
#  (51, 'Justin Wilson', 'British'),
#  (109, 'Jyrki Järvilehto', 'Finnish'),
#  (816, "Jérôme d'Ambrosio", 'Belgian'),
#  (155, 'Kamui Kobayashi', 'Japanese'),
#  (648, 'Karl Kling', 'German'),
#  (91, 'Karl Wendlinger', 'Austrian'),
#  (812, 'Karun Chandhok', 'Indian'),
#  (6, 'Kazuki Nakajima', 'Japanese'),
#  (273, 'Kazuyoshi Hoshino', 'Japanese'),
#  (631, 'Keith Andrews', 'American'),
#  (465, 'Keith Greene', 'British'),
#  (744, 'Ken Downing', 'British'),
#  (582, 'Ken Kavanagh', 'Australian'),
#  (495, 'Ken Miles', 'British'),
#  (781, 'Ken Richardson', 'British'),
#  (663, 'Ken Wharton', 'British'),
#  (664, 'Kenneth McAlpine', 'British'),
#  (186, 'Kenny Acheson', 'British'),
#  (214, 'Kevin Cogan', 'American'),
#  (825, 'Kevin Magnussen', 'Danish'),
#  (272, 'Kunimitsu Takahashi', 'Japanese'),
#  (714, 'Kurt Adolff', 'German'),
#  (379, 'Kurt Ahrens', 'German'),
#  (442, 'Kurt Kuhnke', 'German'),
#  (241, 'Lamberto Leoni', 'Italian'),
#  (651, 'Lance Macklin', 'British'),
#  (508, 'Lance Reventlow', 'American'),
#  (840, 'Lance Stroll', 'Canadian'),
#  (846, 'Lando Norris', 'British'),
#  (674, 'Larry Crockett', 'American'),
#  (256, 'Larry Perkins', 'Australian'),
#  (766, 'Lee Wallard', 'American'),
#  (275, 'Lella Lombardi', 'Italian'),
#  (678, 'Len Duncan', 'American'),
#  (536, 'Len Sutton', 'American'),
#  (316, 'Leo Kinnunen', 'Finnish'),
#  (610, 'Les Leston', 'British'),
#  (790, 'Leslie Johnson', 'British'),
#  (665, 'Leslie Marr', 'British'),
#  (683, 'Leslie Thorne', 'British'),
#  (494, 'Lloyd Ruby', 'American'),
#  (858, 'Logan Sargeant', 'American'),
#  (271, 'Loris Kessel', 'Swiss'),
#  (589, 'Louis Chiron', 'Monegasque'),
#  (627, 'Louis Rosier', 'French'),
#  (69, 'Luca Badoer', 'Italian'),
#  (810, 'Lucas di Grassi', 'Brazilian'),
#  (54, 'Luciano Burti', 'Brazilian'),
#  (376, 'Lucien Bianchi', 'Belgian'),
#  (375, 'Ludovico Scarfiotti', 'Italian'),
#  (786, 'Luigi Fagioli', 'Italian'),
#  (586, 'Luigi Piotti', 'Italian'),
#  (588, 'Luigi Taramazzo', 'Italian'),
#  (633, 'Luigi Villoresi', 'Italian'),
#  (159, 'Luis Pérez-Sala', 'Spanish'),
#  (331, 'Luiz Bueno', 'Brazilian'),
#  (384, 'Luki Botha', 'South African'),
#  (772, 'Mack Hellings', 'American'),
#  (181, 'Manfred Winkelhock', 'German'),
#  (675, 'Manny Ayulo', 'American'),
#  (48, 'Marc Gené', 'Spanish'),
#  (176, 'Marc Surer', 'Swiss'),
#  (754, 'Marcel Balsa', 'French'),
#  (124, 'Marco Apicella', 'Italian'),
#  (828, 'Marcus Ericsson', 'Swedish'),
#  (551, 'Maria de Filippis', 'Italian'),
#  (87, 'Mark Blundell', 'British'),
#  (288, 'Mark Donohue', 'American'),
#  (28, 'Markus Winkelhock', 'German'),
#  (613, 'Marshall Teague', 'American'),
#  (84, 'Martin Brundle', 'British'),
#  (151, 'Martin Donnelly', 'British'),
#  (287, 'Masahiro Hasemi', 'Japanese'),
#  (97, 'Massimiliano Papis', 'Italian'),
#  (487, 'Massimo Natili', 'Italian'),
#  (418, 'Masten Gregory', 'American'),
#  (768, 'Mauri Rose', 'American'),
#  (184, 'Mauro Baldi', 'Italian'),
#  (127, 'Maurício Gugelmin', 'Brazilian'),
#  (820, 'Max Chilton', 'British'),
#  (349, 'Max Jean', 'French'),
#  (720, 'Max de Terra', 'Swiss'),
#  (492, 'Menato Boffa', 'Italian'),
#  (121, 'Michael Andretti', 'American'),
#  (143, 'Michael Bartels', 'German'),
#  (247, 'Michael Bleekemolen', 'Dutch'),
#  (480, 'Michael May', 'Swiss'),
#  (277, 'Michel Leclère', 'French'),
#  (854, 'Mick Schumacher', 'German'),
#  (215, 'Miguel Ángel Guerra', 'Argentine'),
#  (63, 'Mika Salo', 'Finnish'),
#  (329, 'Mike Beuttler', 'British'),
#  (392, 'Mike Fisher', 'American'),
#  (305, 'Mike Hailwood', 'British'),
#  (472, 'Mike Harris', 'South African'),
#  (617, 'Mike MacDowel', 'British'),
#  (565, 'Mike Magill', 'American'),
#  (673, 'Mike Nazaruk', 'American'),
#  (387, 'Mike Parkes', 'British'),
#  (662, 'Mike Sparken', 'French'),
#  (374, 'Mike Spence', 'British'),
#  (540, 'Mike Taylor', 'British'),
#  (191, 'Mike Thackwell', 'New Zealander'),
#  (283, 'Mike Wilds', 'British'),
#  (263, 'Mikko Kozarowitzky', 'Finnish'),
#  (382, 'Moisés Solana', 'Mexican'),
#  (795, 'Myron Fohr', 'American'),
#  (432, 'Mário de Araújo Cabral', 'Portuguese'),
#  (330, 'Nanni Galli', 'Italian'),
#  (144, 'Naoki Hattori', 'Japanese'),
#  (39, 'Narain Karthikeyan', 'Indian'),
#  (439, 'Nasif Estéfano', 'Argentine'),
#  (800, 'Nello Pagani', 'Italian'),
#  (12, 'Nelson Piquet Jr.', 'Brazilian'),
#  (410, 'Neville Lederle', 'South African'),
#  (849, 'Nicholas Latifi', 'Canadian'),
#  (2, 'Nick Heidfeld', 'German'),
#  (807, 'Nico Hülkenberg', 'German'),
#  (78, 'Nicola Larini', 'Italian'),
#  (53, 'Nicolas Kiesa', 'Danish'),
#  (853, 'Nikita Mazepin', 'Russian'),
#  (425, 'Nino Vaccarella', 'Italian'),
#  (82, 'Norberto Fontana', 'Argentine'),
#  (274, 'Noritake Takahara', 'Japanese'),
#  (856, 'Nyck de Vries', 'Dutch'),
#  (106, 'Olivier Beretta', 'Monegasque'),
#  (482, 'Olivier Gendebien', 'Belgian'),
#  (129, 'Olivier Grouillard', 'French'),
#  (44, 'Olivier Panis', 'French'),
#  (670, 'Onofre Marimón', 'Argentine'),
#  (695, 'Oscar Gálvez', 'Argentine'),
#  (165, 'Oscar Larrauri', 'Argentine'),
#  (857, 'Oscar Piastri', 'Australian'),
#  (711, 'Oswald Karch', 'German'),
#  (285, 'Otto Stuppacher', 'Austrian'),
#  (638, 'Ottorino Volonterio', 'Swiss'),
#  (649, 'Pablo Birger', 'Argentine'),
#  (580, 'Paco Godia', 'Spanish'),
#  (310, 'Paddy Driver', 'South African'),
#  (147, 'Paolo Barilla', 'Italian'),
#  (169, 'Pascal Fabre', 'French'),
#  (836, 'Pascal Wehrlein', 'German'),
#  (813, 'Pastor Maldonado', 'Venezuelan'),
#  (559, 'Pat Flaherty', 'American'),
#  (597, "Pat O'Connor", 'American'),
#  (40, 'Patrick Friesacher', 'Austrian'),
#  (236, 'Patrick Gaillard', 'French'),
#  (258, 'Patrick Nève', 'Belgian'),
#  (175, 'Patrick Tambay', 'French'),
#  (108, 'Paul Belmondo', 'French'),
#  (585, 'Paul Emery', 'British'),
#  (621, 'Paul England', 'Australian'),
#  (632, 'Paul Frère', 'Belgian'),
#  (510, 'Paul Goldsmith', 'American'),
#  (406, 'Paul Hawkins', 'Australian'),
#  (756, 'Paul Pietsch', 'German'),
#  (555, 'Paul Russo', 'American'),
#  (814, 'Paul di Resta', 'British'),
#  (142, 'Pedro Chaves', 'Portuguese'),
#  (64, 'Pedro Diniz', 'Brazilian'),
#  (83, 'Pedro Lamy', 'Portuguese'),
#  (37, 'Pedro de la Rosa', 'Spanish'),
#  (135, 'Perry McCarthy', 'British'),
#  (353, 'Pete Lovely', 'American'),
#  (397, 'Peter Arundell', 'British'),
#  (569, 'Peter Ashdown', 'British'),
#  (448, 'Peter Broeker', 'Canadian'),
#  (320, 'Peter Gethin', 'British'),
#  (721, 'Peter Hirt', 'Swiss'),
#  (488, 'Peter Monteverdi', 'Swiss'),
#  (309, 'Peter Revson', 'American'),
#  (493, 'Peter Ryan', 'Canadian'),
#  (661, 'Peter Walker', 'British'),
#  (367, 'Peter Westbury', 'British'),
#  (687, 'Peter Whitehead', 'British'),
#  (362, 'Peter de Klerk', 'South African'),
#  (576, 'Phil Cade', 'American'),
#  (777, 'Philip Fotheringham-Parker', 'British'),
#  (113, 'Philippe Adams', 'Belgian'),
#  (112, 'Philippe Alliot', 'French'),
#  (166, 'Philippe Streiff', 'French'),
#  (741, 'Philippe Étancelin', 'French'),
#  (160, 'Piercarlo Ghinzani', 'Italian'),
#  (94, 'Pierluigi Martini', 'Italian'),
#  (722, 'Piero Carini', 'Italian'),
#  (544, 'Piero Drogo', 'Italian'),
#  (760, 'Piero Dusio', 'Italian'),
#  (634, 'Piero Scotti', 'Italian'),
#  (842, 'Pierre Gasly', 'French'),
#  (773, 'Pierre Levegh', 'French'),
#  (162, 'Pierre-Henri Raphanel', 'French'),
#  (361, 'Piers Courage', 'British'),
#  (850, 'Pietro Fittipaldi', 'Brazilian'),
#  (669, 'Prince Bira', 'Thai'),
#  (23, 'Ralf Schumacher', 'German'),
#  (52, 'Ralph Firman', 'Irish'),
#  (196, 'Raul Boesel', 'Brazilian'),
#  (561, 'Ray Crawford', 'American'),
#  (415, 'Ray Reed', 'South African'),
#  (793, 'Raymond Sommer', 'French'),
#  (517, 'Red Amick', 'American'),
#  (686, 'Reg Parnell', 'British'),
#  (317, 'Reine Wisell', 'Swedish'),
#  (489, 'Renato Pirocchi', 'Italian'),
#  (254, 'Renzo Zorzi', 'Italian'),
#  (218, 'Ricardo Londoño', 'Colombian'),
#  (454, 'Ricardo Rodríguez', 'Mexican'),
#  (73, 'Ricardo Rosset', 'Brazilian'),
#  (41, 'Ricardo Zonta', 'Brazilian'),
#  (217, 'Ricardo Zunino', 'Argentine'),
#  (204, 'Riccardo Paletti', 'Italian'),
#  (119, 'Riccardo Patrese', 'Italian'),
#  (370, 'Richard Attwood', 'British'),
#  (308, 'Richard Robarts', 'British'),
#  (386, 'Richie Ginther', 'American'),
#  (313, 'Rikky von Opel', 'Liechtensteiner'),
#  (837, 'Rio Haryanto', 'Indonesian'),
#  (469, 'Rob Schroeder', 'British'),
#  (458, 'Rob Slotemaker', 'Dutch'),
#  (38, 'Robert Doornbos', 'Dutch'),
#  (602, 'Robert La Caze', 'French'),
#  (626, 'Robert Manzon', 'French'),
#  (737, "Robert O'Brien", 'American'),
#  (499, 'Roberto Bonomi', 'Argentine'),
#  (424, 'Roberto Bussinello', 'Italian'),
#  (195, 'Roberto Guerrero', 'Colombian'),
#  (444, 'Roberto Lippi', 'Italian'),
#  (833, 'Roberto Merhi', 'Spanish'),
#  (643, 'Roberto Mieres', 'Argentine'),
#  (90, 'Roberto Moreno', 'Brazilian'),
#  (739, 'Robin Montgomerie-Charrington', 'British'),
#  (378, 'Robin Widdows', 'British'),
#  (449, 'Rodger Ward', 'American'),
#  (690, 'Rodney Nuckey', 'British'),
#  (295, 'Roelof Wunderink', 'Dutch'),
#  (736, 'Roger Laurent', 'Belgian'),
#  (671, 'Roger Loyer', 'French'),
#  (468, 'Roger Penske', 'American'),
#  (335, 'Roger Williamson', 'British'),
#  (107, 'Roland Ratzenberger', 'Austrian'),
#  (243, 'Rolf Stommelen', 'German'),
#  (154, 'Romain Grosjean', 'French'),
#  (541, 'Ron Flockhart', 'British'),
#  (405, 'Ronnie Bucknum', 'American'),
#  (238, 'Ronnie Peterson', 'Swedish'),
#  (456, 'Roy Salvadori', 'British'),
#  (22, 'Rubens Barrichello', 'Brazilian'),
#  (723, 'Rudi Fischer', 'Swiss'),
#  (710, 'Rudolf Krause', 'East German'),
#  (755, 'Rudolf Schoeller', 'Swiss'),
#  (211, 'Rupert Keegan', 'British'),
#  (29, 'Sakon Yamamoto', 'Japanese'),
#  (611, 'Sam Hanks', 'American'),
#  (344, 'Sam Posey', 'American'),
#  (368, 'Sam Tingle', 'Rhodesian'),
#  (138, 'Satoru Nakajima', 'Japanese'),
#  (26, 'Scott Speed', 'American'),
#  (845, 'Sergey Sirotkin', 'Russian'),
#  (644, 'Sergio Mantovani', 'Italian'),
#  (815, 'Sergio Pérez', 'Mexican'),
#  (75, 'Shinji Nakano', 'Japanese'),
#  (523, 'Shorty Templeman', 'American'),
#  (216, 'Siegfried Stohr', 'Italian'),
#  (351, 'Silvio Moser', 'Swiss'),
#  (342, 'Skip Barber', 'American'),
#  (201, 'Slim Borgudd', 'Swedish'),
#  (185, 'Stefan Bellof', 'German'),
#  (140, 'Stefan Johansson', 'Swedish'),
#  (131, 'Stefano Modena', 'Italian'),
#  (226, 'Stephen South', 'British'),
#  (838, 'Stoffel Vandoorne', 'Belgian'),
#  (590, 'Stuart Lewis-Evans', 'British'),
#  (72, 'Stéphane Sarrazin', 'French'),
#  (474, 'Syd van der Vyver', 'South African'),
#  (7, 'Sébastien Bourdais', 'French'),
#  (67, 'Sébastien Buemi', 'Swiss'),
#  (89, 'Taki Inoue', 'Japanese'),
#  (11, 'Takuma Sato', 'Japanese'),
#  (58, 'Tarso Marques', 'Brazilian'),
#  (652, 'Ted Whiteaway', 'British'),
#  (269, 'Teddy Pilette', 'Belgian'),
#  (170, 'Teo Fabi', 'Italian'),
#  (713, 'Theo Fitzau', 'East German'),
#  (692, 'Theo Helfrich', 'German'),
#  (123, 'Thierry Boutsen', 'Belgian'),
#  (452, 'Thomas Monarch', 'American'),
#  (33, 'Tiago Monteiro', 'Portuguese'),
#  (227, 'Tiff Needell', 'British'),
#  (441, 'Tim Parnell', 'British'),
#  (314, 'Tim Schenken', 'Australian'),
#  (470, 'Timmy Mayer', 'American'),
#  (10, 'Timo Glock', 'German'),
#  (311, 'Tom Belsø', 'Danish'),
#  (605, 'Tom Bridger', 'British'),
#  (393, 'Tom Jones', 'American'),
#  (252, 'Tom Pryce', 'British'),
#  (210, 'Tommy Byrne', 'Irish'),
#  (61, 'Tomáš Enge', 'Czech'),
#  (780, 'Toni Branca', 'Swiss'),
#  (724, 'Toni Ulmen', 'German'),
#  (529, 'Tony Bettenhausen', 'American'),
#  (294, 'Tony Brise', 'British'),
#  (479, 'Tony Brooks', 'British'),
#  (705, 'Tony Crook', 'British'),
#  (738, 'Tony Gaze', 'Australian'),
#  (408, 'Tony Maggs', 'South African'),
#  (459, 'Tony Marsh', 'British'),
#  (666, 'Tony Rolt', 'British'),
#  (438, 'Tony Settember', 'American'),
#  (464, 'Tony Shelly', 'New Zealander'),
#  (245, 'Tony Trimmer', 'British'),
#  (68, 'Toranosuke Takagi', 'Japanese'),
#  (297, 'Torsten Palm', 'Swedish'),
#  (126, 'Toshio Suzuki', 'Japanese'),
#  (640, 'Toulo de Graffenried', 'Swiss'),
#  (677, 'Travis Webb', 'American'),
#  (409, 'Trevor Blokdyk', 'South African'),
#  (401, 'Trevor Taylor', 'British'),
#  (526, 'Troy Ruttman', 'American'),
#  (79, 'Ukyo Katayama', 'Japanese'),
#  (620, 'Umberto Maglioli', 'Italian'),
#  (267, 'Vern Schuppan', 'Australian'),
#  (350, 'Vic Elford', 'British'),
#  (398, 'Vic Wilson', 'British'),
#  (80, 'Vincenzo Sospiri', 'Italian'),
#  (808, 'Vitaly Petrov', 'Russian'),
#  (24, 'Vitantonio Liuzzi', 'Italian'),
#  (230, 'Vittorio Brambilla', 'Italian'),
#  (161, 'Volker Weidler', 'German'),
#  (796, 'Walt Ader', 'American'),
#  (771, 'Walt Brown', 'American'),
#  (654, 'Walt Faulkner', 'American'),
#  (433, 'Walt Hansgen', 'American'),
#  (286, 'Warwick Brown', 'Australian'),
#  (530, 'Wayne Weiler', 'American'),
#  (829, 'Will Stevens', 'British'),
#  (712, 'Willi Heeks', 'German'),
#  (435, 'Willy Mairesse', 'Belgian'),
#  (290, 'Wilson Fittipaldi', 'Brazilian'),
#  (455, 'Wolfgang Seidel', 'German'),
#  (114, 'Yannick Dalmas', 'French'),
#  (34, 'Yuji Ide', 'Japanese'),
#  (852, 'Yuki Tsunoda', 'Japanese'),
#  (704, 'Yves Cabantous', 'French'),
#  (47, 'Zsolt Baumgartner', 'Hungarian'),
#  (625, 'Élie Bayol', 'French'),
#  (103, 'Éric Bernard', 'French'),
#  (100, 'Érik Comas', 'French'),
#  (806, 'Óscar González', 'Uruguayan')]

# %% [markdown]
# ## 17. Are there any constructors who never scored a point? if so mention their name and how many races they participated in?

# %%
# %%sql
# select c.constructorid, c.name, sum(points) as tot_points, count(1) as no_races
# from constructors c
# left join constructor_results cr on c.constructorid = cr.constructorid
# group by 1,2
# having sum(points) = 0
# order by 4 desc, 2;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 82 rows affected.
# [(42, 'Coloni', Decimal('0'), 65),
#  (164, 'HRT', Decimal('0'), 57),
#  (207, 'Caterham', Decimal('0'), 56),
#  (44, 'Euro Brun', Decimal('0'), 46),
#  (50, 'RAM', Decimal('0'), 44),
#  (205, 'Lotus', Decimal('0'), 38),
#  (166, 'Virgin', Decimal('0'), 38),
#  (30, 'Pacific', Decimal('0'), 33),
#  (60, 'Merzario', Decimal('0'), 31),
#  (36, 'Fondmetal', Decimal('0'), 29),
#  (28, 'Forti', Decimal('0'), 27),
#  (52, 'Spirit', Decimal('0'), 25),
#  (31, 'Simtek', Decimal('0'), 21),
#  (40, 'Lambo', Decimal('0'), 16),
#  (86, 'De Tomaso', Decimal('0'), 14),
#  (47, 'Life', Decimal('0'), 14),
#  (13, 'MF1', Decimal('0'), 14),
#  (198, 'McLaren-Alfa Romeo', Decimal('0'), 10),
#  (92, 'Scirocco', Decimal('0'), 10),
#  (38, 'Andrea Moda', Decimal('0'), 8),
#  (70, 'Boro', Decimal('0'), 8),
#  (99, 'Emeryson', Decimal('0'), 8),
#  (74, 'Maki', Decimal('0'), 8),
#  (65, 'Martini', Decimal('0'), 8),
#  (77, 'Trojan', Decimal('0'), 8),
#  (97, 'Gilby', Decimal('0'), 7),
#  (199, 'March-Alfa Romeo', Decimal('0'), 7),
#  (85, 'Bellasi', Decimal('0'), 6),
#  (101, 'JBW', Decimal('0'), 6),
#  (68, 'LEC', Decimal('0'), 5),
#  (106, 'Scarab', Decimal('0'), 5),
#  (78, 'Amon', Decimal('0'), 4),
#  (14, 'Spyker MF1', Decimal('0'), 4),
#  (79, 'Token', Decimal('0'), 4),
#  (125, 'Connaught', Decimal('0'), 3),
#  (174, 'De Tomaso-Osca', Decimal('0'), 3),
#  (113, 'Kurtis Kraft', Decimal('0'), 3),
#  (89, 'LDS', Decimal('0'), 3),
#  (201, 'Lotus-Pratt &amp; Whitney', Decimal('0'), 3),
#  (62, 'Rebaque', Decimal('0'), 3),
#  (104, 'Behra-Porsche', Decimal('0'), 2),
#  (115, 'Christensen', Decimal('0'), 2),
#  (169, 'Cooper-Borgward', Decimal('0'), 2),
#  (192, 'Cooper-Ferrari', Decimal('0'), 2),
#  (186, 'Cooper-Ford', Decimal('0'), 2),
#  (175, 'De Tomaso-Alfa Romeo', Decimal('0'), 2),
#  (61, 'Kauhsen', Decimal('0'), 2),
#  (72, 'Kojima', Decimal('0'), 2),
#  (114, 'Kuzma', Decimal('0'), 2),
#  (184, 'LDS-Climax', Decimal('0'), 2),
#  (177, 'Lotus-Borgward', Decimal('0'), 2),
#  (173, 'Lotus-Maserati', Decimal('0'), 2),
#  (76, 'Lyncar', Decimal('0'), 2),
#  (203, 'Shadow-Matra', Decimal('0'), 2),
#  (71, 'Apollon', Decimal('0'), 1),
#  (197, 'BRM-Ford', Decimal('0'), 1),
#  (84, 'Connew', Decimal('0'), 1),
#  (193, 'Cooper-ATS', Decimal('0'), 1),
#  (178, 'Cooper-Alfa Romeo', Decimal('0'), 1),
#  (168, 'Cooper-OSCA', Decimal('0'), 1),
#  (179, 'De Tomaso-Ferrari', Decimal('0'), 1),
#  (96, 'Derrington', Decimal('0'), 1),
#  (120, 'Dunn', Decimal('0'), 1),
#  (100, 'ENB', Decimal('0'), 1),
#  (121, 'Elder', Decimal('0'), 1),
#  (116, 'Ewing', Decimal('0'), 1),
#  (102, 'Ferguson', Decimal('0'), 1),
#  (123, 'Fry', Decimal('0'), 1),
#  (128, 'Gordini', Decimal('0'), 1),
#  (185, 'LDS-Alfa Romeo', Decimal('0'), 1),
#  (103, 'MBM', Decimal('0'), 1),
#  (69, 'McGuire', Decimal('0'), 1),
#  (112, 'Meskowski', Decimal('0'), 1),
#  (119, 'Moore', Decimal('0'), 1),
#  (127, 'OSCA', Decimal('0'), 1),
#  (83, 'Politoys', Decimal('0'), 1),
#  (90, 'Protos', Decimal('0'), 1),
#  (93, 'RE', Decimal('0'), 1),
#  (91, 'Shannon', Decimal('0'), 1),
#  (98, 'Stebro', Decimal('0'), 1),
#  (122, 'Sutton', Decimal('0'), 1),
#  (124, 'Tec-Mec', Decimal('0'), 1)]

# %% [markdown]
# ## 18. Mention the drivers who have won more than 50 races.

# %%
# %%sql
# select d.driverid, concat(forename, ' ', surname) as driver_name, count(1) as no_of_win
# from drivers d
# left join driver_standings ds on d.driverid = ds.driverid
# where position = 1
# group by 1,2
# having count(1) >= 50;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 5 rows affected.
# [(1, 'Lewis Hamilton', 125),
#  (30, 'Michael Schumacher', 121),
#  (20, 'Sebastian Vettel', 63),
#  (117, 'Alain Prost', 79),
#  (4, 'Fernando Alonso', 52)]

# %% [markdown]
# ## 19. Identify the podium finishers of each race in 2022 season

# %%
# %%sql
# select r.name, concat(forename,' ',surname) as drivers, re.position as rank
# from results re
# join races r on re.raceid = r.raceid
# join drivers d on re.driverid = d.driverid
# where position in (1,2,3)
# and year = 2022
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 66 rows affected.
# [('Bahrain Grand Prix', 'Charles Leclerc', 1),
#  ('Bahrain Grand Prix', 'Carlos Sainz', 2),
#  ('Bahrain Grand Prix', 'Lewis Hamilton', 3),
#  ('Saudi Arabian Grand Prix', 'Max Verstappen', 1),
#  ('Saudi Arabian Grand Prix', 'Charles Leclerc', 2),
#  ('Saudi Arabian Grand Prix', 'Carlos Sainz', 3),
#  ('Australian Grand Prix', 'Charles Leclerc', 1),
#  ('Australian Grand Prix', 'Sergio Pérez', 2),
#  ('Australian Grand Prix', 'George Russell', 3),
#  ('Emilia Romagna Grand Prix', 'Max Verstappen', 1),
#  ('Emilia Romagna Grand Prix', 'Sergio Pérez', 2),
#  ('Emilia Romagna Grand Prix', 'Lando Norris', 3),
#  ('Miami Grand Prix', 'Max Verstappen', 1),
#  ('Miami Grand Prix', 'Charles Leclerc', 2),
#  ('Miami Grand Prix', 'Carlos Sainz', 3),
#  ('Spanish Grand Prix', 'Max Verstappen', 1),
#  ('Spanish Grand Prix', 'Sergio Pérez', 2),
#  ('Spanish Grand Prix', 'George Russell', 3),
#  ('Monaco Grand Prix', 'Sergio Pérez', 1),
#  ('Monaco Grand Prix', 'Carlos Sainz', 2),
#  ('Monaco Grand Prix', 'Max Verstappen', 3),
#  ('Azerbaijan Grand Prix', 'Max Verstappen', 1),
#  ('Azerbaijan Grand Prix', 'Sergio Pérez', 2),
#  ('Azerbaijan Grand Prix', 'George Russell', 3),
#  ('Canadian Grand Prix', 'Max Verstappen', 1),
#  ('Canadian Grand Prix', 'Carlos Sainz', 2),
#  ('Canadian Grand Prix', 'Lewis Hamilton', 3),
#  ('British Grand Prix', 'Carlos Sainz', 1),
#  ('British Grand Prix', 'Sergio Pérez', 2),
#  ('British Grand Prix', 'Lewis Hamilton', 3),
#  ('Austrian Grand Prix', 'Charles Leclerc', 1),
#  ('Austrian Grand Prix', 'Max Verstappen', 2),
#  ('Austrian Grand Prix', 'Lewis Hamilton', 3),
#  ('French Grand Prix', 'Max Verstappen', 1),
#  ('French Grand Prix', 'Lewis Hamilton', 2),
#  ('French Grand Prix', 'George Russell', 3),
#  ('Hungarian Grand Prix', 'Max Verstappen', 1),
#  ('Hungarian Grand Prix', 'Lewis Hamilton', 2),
#  ('Hungarian Grand Prix', 'George Russell', 3),
#  ('Belgian Grand Prix', 'Max Verstappen', 1),
#  ('Belgian Grand Prix', 'Sergio Pérez', 2),
#  ('Belgian Grand Prix', 'Carlos Sainz', 3),
#  ('Dutch Grand Prix', 'Max Verstappen', 1),
#  ('Dutch Grand Prix', 'George Russell', 2),
#  ('Dutch Grand Prix', 'Charles Leclerc', 3),
#  ('Italian Grand Prix', 'Max Verstappen', 1),
#  ('Italian Grand Prix', 'Charles Leclerc', 2),
#  ('Italian Grand Prix', 'George Russell', 3),
#  ('Singapore Grand Prix', 'Sergio Pérez', 1),
#  ('Singapore Grand Prix', 'Charles Leclerc', 2),
#  ('Singapore Grand Prix', 'Carlos Sainz', 3),
#  ('Japanese Grand Prix', 'Max Verstappen', 1),
#  ('Japanese Grand Prix', 'Sergio Pérez', 2),
#  ('Japanese Grand Prix', 'Charles Leclerc', 3),
#  ('United States Grand Prix', 'Max Verstappen', 1),
#  ('United States Grand Prix', 'Lewis Hamilton', 2),
#  ('United States Grand Prix', 'Charles Leclerc', 3),
#  ('Mexico City Grand Prix', 'Max Verstappen', 1),
#  ('Mexico City Grand Prix', 'Lewis Hamilton', 2),
#  ('Mexico City Grand Prix', 'Sergio Pérez', 3),
#  ('Brazilian Grand Prix', 'George Russell', 1),
#  ('Brazilian Grand Prix', 'Lewis Hamilton', 2),
#  ('Brazilian Grand Prix', 'Carlos Sainz', 3),
#  ('Abu Dhabi Grand Prix', 'Max Verstappen', 1),
#  ('Abu Dhabi Grand Prix', 'Charles Leclerc', 2),
#  ('Abu Dhabi Grand Prix', 'Sergio Pérez', 3)]

# %% [markdown]
# ## 20. For 2022 season, mention the points structure for each position. i.e. how many points are awarded to each race finished position.

# %%
# %%sql
# -- First part of the query is to determine how many points they will receive for each corresponding position
# select distinct concat('position = ',coalesce(position::text, 'null')) as category, points
# from results re
# join races r on re.raceid = r.raceid
# where year = 2022
# and rank != 1
# union all
# -- The second part of the query is designed that when the rank is 1, they will receive an additional 1 point
# select 'rank = 1' as category,
# max(case when rank = 1 then 1 end) as points
# from results re
# join races r on re.raceid = r.raceid
# where year = 2022
# order by 2 desc, 1;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 22 rows affected.
# [('position = 1', Decimal('25')),
#  ('position = 2', Decimal('18')),
#  ('position = 3', Decimal('15')),
#  ('position = 4', Decimal('12')),
#  ('position = 5', Decimal('10')),
#  ('position = 6', Decimal('8')),
#  ('position = 7', Decimal('6')),
#  ('position = 8', Decimal('4')),
#  ('position = 9', Decimal('2')),
#  ('position = 10', Decimal('1')),
#  ('rank = 1', Decimal('1')),
#  ('position = 11', Decimal('0')),
#  ('position = 12', Decimal('0')),
#  ('position = 13', Decimal('0')),
#  ('position = 14', Decimal('0')),
#  ('position = 15', Decimal('0')),
#  ('position = 16', Decimal('0')),
#  ('position = 17', Decimal('0')),
#  ('position = 18', Decimal('0')),
#  ('position = 19', Decimal('0')),
#  ('position = 20', Decimal('0')),
#  ('position = null', Decimal('0'))]

# %% [markdown]
# ## 21. How many drivers participated in 2022 season?

# %%
# %%sql
# select count(distinct(d.driverid)) as no_drivers_in_2022
# from races r
# join driver_standings ds on r.raceid = ds.raceid
# join drivers d on ds.driverid = d.driverid
# where year = 2022;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 1 rows affected.
# [(22,)]

# %% [markdown]
# ## 22. How many races has the top 5 constructors won in the last 10 years.

# %%
# %%sql
# select name, no_win_in_last10yrs
# from(
# 	select cs.constructorid, c.name, count(1) as no_win_in_last10yrs,
# 	dense_rank() over(order by count(1) desc) as rk
# 	from constructor_standings cs
# 	join constructors c on cs.constructorid = c.constructorid
# 	join races r on cs.raceid = r.raceid
# 	where position = 1
# 	and r.date between (current_date - interval '10 years') and current_date
# 	group by 1,2
# 	)x -- Subquery to rank the total win from last 10 year to current date from highest to lowest
# where rk <= 5;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 5 rows affected.
# [('Mercedes', 145),
#  ('Red Bull', 32),
#  ('Ferrari', 13),
#  ('Alfa Romeo', 1),
#  ('McLaren', 1)]

# %% [markdown]
# ## 23. Display the winners of every sprint so far in F1

# %%
# %%sql
# select year, concat(forename,' ', surname) as drivers, r.name
# from sprint_results sr
# join drivers d on sr.driverid = d.driverid
# join races r on r.raceid = sr.raceid
# where position = 1
# order by 1,2;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 6 rows affected.
# [(2021, 'Max Verstappen', 'British Grand Prix'),
#  (2021, 'Valtteri Bottas', 'São Paulo Grand Prix'),
#  (2021, 'Valtteri Bottas', 'Italian Grand Prix'),
#  (2022, 'George Russell', 'Brazilian Grand Prix'),
#  (2022, 'Max Verstappen', 'Austrian Grand Prix'),
#  (2022, 'Max Verstappen', 'Emilia Romagna Grand Prix')]

# %% [markdown]
# ## 24. Find the driver who has the most no of Did Not Qualify during the race.

# %%
# %%sql
# select drivers, no_not_qualify
# from(
# 	select concat(forename,' ',surname) as drivers, count(1) as no_not_qualify,
# 	dense_rank() over(order by count(1) desc) as rk
# 	from results r
# 	join status s on r.statusid = s.statusid
# 	join drivers d on r.driverid = d.driverid
# 	where status = 'Did not qualify'
# 	group by 1
# 	) x -- Subquery rank the total number of race a driver did not qualify from highest to lowest.
# where rk = 1;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 1 rows affected.
# [('Arturo Merzario', 24)]

# %% [markdown]
# ## 25. During the last race of 2022 season, identify the drivers who did not finish the race and the reason for it.

# %%
# %%sql
# select r.name, concat(forename,' ',surname) as drivers, status as reason
# from results re
# join status s on re.statusid = s.statusid
# join races r on re.raceid = r.raceid
# join drivers d on re.driverid = d.driverid
# where re.raceid = (select max(raceid) from races where year = 2022) -- Subquery of the last race in year 2022
# and status != 'Finished';
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 9 rows affected.
# [('Abu Dhabi Grand Prix', 'Guanyu Zhou', '+1 Lap'),
#  ('Abu Dhabi Grand Prix', 'Alexander Albon', '+1 Lap'),
#  ('Abu Dhabi Grand Prix', 'Pierre Gasly', '+1 Lap'),
#  ('Abu Dhabi Grand Prix', 'Valtteri Bottas', '+1 Lap'),
#  ('Abu Dhabi Grand Prix', 'Mick Schumacher', '+1 Lap'),
#  ('Abu Dhabi Grand Prix', 'Kevin Magnussen', '+1 Lap'),
#  ('Abu Dhabi Grand Prix', 'Lewis Hamilton', 'Hydraulics'),
#  ('Abu Dhabi Grand Prix', 'Nicholas Latifi', 'Collision damage'),
#  ('Abu Dhabi Grand Prix', 'Fernando Alonso', 'Water leak')]

# %% [markdown]
# ## 26. What is the average lap time for each F1 circuit. Sort based on least lap time.

# %%
# %%sql
# select c.circuitid, c.name, c.location, c.country, avg(l.time) as avg_lap_time
# from lap_times l
# join races r on l.raceid = r.raceid
# right join circuits c on r.circuitid = c.circuitid
# group by 1,2,3,4
# order by 5
# limit 10; -- Avoid for long output
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 77 rows affected.
# [(70, 'Red Bull Ring', 'Spielberg', 'Austria', datetime.timedelta(seconds=74, microseconds=406069)),
#  (19, 'Indianapolis Motor Speedway', 'Indianapolis', 'USA', datetime.timedelta(seconds=78, microseconds=880697)),
#  (39, 'Circuit Park Zandvoort', 'Zandvoort', 'Netherlands', datetime.timedelta(seconds=79, microseconds=59552)),
#  (8, 'Circuit de Nevers Magny-Cours', 'Magny Cours', 'France', datetime.timedelta(seconds=81, microseconds=948936)),
#  (18, 'Autódromo José Carlos Pace', 'São Paulo', 'Brazil', datetime.timedelta(seconds=84, microseconds=302864)),
#  (32, 'Autódromo Hermanos Rodríguez', 'Mexico City', 'Mexico', datetime.timedelta(seconds=85, microseconds=143594)),
#  (75, 'Autódromo Internacional do Algarve', 'Portimão', 'Portugal', datetime.timedelta(seconds=85, microseconds=383201)),
#  (26, 'Circuito de Jerez', 'Jerez de la Frontera', 'Spain', datetime.timedelta(seconds=87, microseconds=72146)),
#  (11, 'Hungaroring', 'Budapest', 'Hungary', datetime.timedelta(seconds=87, microseconds=709660)),
#  (6, 'Circuit de Monaco', 'Monte-Carlo', 'Monaco', datetime.timedelta(seconds=87, microseconds=732309)),
#  (27, 'Autódromo do Estoril', 'Estoril', 'Portugal', datetime.timedelta(seconds=88, microseconds=531930)),
#  (4, 'Circuit de Barcelona-Catalunya', 'Montmeló', 'Spain', datetime.timedelta(seconds=89, microseconds=80471)),
#  (10, 'Hockenheimring', 'Hockenheim', 'Germany', datetime.timedelta(seconds=89, microseconds=167088)),
#  (7, 'Circuit Gilles Villeneuve', 'Montreal', 'Canada', datetime.timedelta(seconds=90, microseconds=91827)),
#  (78, 'Losail International Circuit', 'Al Daayen', 'Qatar', datetime.timedelta(seconds=90, microseconds=765272)),
#  (14, 'Autodromo Nazionale di Monza', 'Monza', 'Italy', datetime.timedelta(seconds=91, microseconds=283238)),
#  (21, 'Autodromo Enzo e Dino Ferrari', 'Imola', 'Italy', datetime.timedelta(seconds=91, microseconds=450749)),
#  (68, 'Buddh International Circuit', 'Uttar Pradesh', 'India', datetime.timedelta(seconds=92, microseconds=992391)),
#  (5, 'Istanbul Park', 'Istanbul', 'Turkey', datetime.timedelta(seconds=94, microseconds=791904)),
#  (20, 'Nürburgring', 'Nürburg', 'Germany', datetime.timedelta(seconds=95, microseconds=474237)),
#  (25, 'Autódromo Juan y Oscar Gálvez', 'Buenos Aires', 'Argentina', datetime.timedelta(seconds=95, microseconds=490434)),
#  (1, 'Albert Park Grand Prix Circuit', 'Melbourne', 'Australia', datetime.timedelta(seconds=97, microseconds=496572)),
#  (16, 'Fuji Speedway', 'Oyama', 'Japan', datetime.timedelta(seconds=98, microseconds=11794)),
#  (3, 'Bahrain International Circuit', 'Sakhir', 'Bahrain', datetime.timedelta(seconds=99, microseconds=831549)),
#  (79, 'Miami International Autodrome', 'Miami', 'USA', datetime.timedelta(seconds=99, microseconds=879371)),
#  (34, 'Circuit Paul Ricard', 'Le Castellet', 'France', datetime.timedelta(seconds=101, microseconds=222131)),
#  (9, 'Silverstone Circuit', 'Silverstone', 'UK', datetime.timedelta(seconds=102, microseconds=64484)),
#  (22, 'Suzuka Circuit', 'Suzuka', 'Japan', datetime.timedelta(seconds=104, microseconds=816603)),
#  (71, 'Sochi Autodrom', 'Sochi', 'Russia', datetime.timedelta(seconds=106, microseconds=137356)),
#  (12, 'Valencia Street Circuit', 'Valencia', 'Spain', datetime.timedelta(seconds=106, microseconds=225759)),
#  (24, 'Yas Marina Circuit', 'Abu Dhabi', 'UAE', datetime.timedelta(seconds=106, microseconds=454833)),
#  (69, 'Circuit of the Americas', 'Austin', 'USA', datetime.timedelta(seconds=106, microseconds=895897)),
#  (17, 'Shanghai International Circuit', 'Shanghai', 'China', datetime.timedelta(seconds=107, microseconds=118693)),
#  (2, 'Sepang International Circuit', 'Kuala Lumpur', 'Malaysia', datetime.timedelta(seconds=110, microseconds=46511)),
#  (15, 'Marina Bay Street Circuit', 'Marina Bay', 'Singapore', datetime.timedelta(seconds=119, microseconds=464969)),
#  (13, 'Circuit de Spa-Francorchamps', 'Spa', 'Belgium', datetime.timedelta(seconds=121, microseconds=203697)),
#  (73, 'Baku City Circuit', 'Baku', 'Azerbaijan', datetime.timedelta(seconds=125, microseconds=624787)),
#  (77, 'Jeddah Corniche Circuit', 'Jeddah', 'Saudi Arabia', datetime.timedelta(seconds=129, microseconds=60861)),
#  (35, 'Korean International Circuit', 'Yeongam County', 'Korea', datetime.timedelta(seconds=131, microseconds=153806)),
#  (76, 'Autodromo Internazionale del Mugello', 'Mugello', 'Italy', datetime.timedelta(seconds=141, microseconds=405246)),
#  (53, 'Rouen-Les-Essarts', 'Rouen', 'France', None),
#  (65, 'Pescara Circuit', 'Pescara', 'Italy', None),
#  (38, 'Brands Hatch', 'Kent', 'UK', None),
#  (59, 'Circuito da Boavista', 'Oporto', 'Portugal', None),
#  (48, 'Mosport International Raceway', 'Ontario', 'Canada', None),
#  (66, 'Circuit Bremgarten', 'Bern', 'Switzerland', None),
#  (60, 'Riverside International Raceway', 'California', 'USA', None),
#  (50, 'Nivelles-Baulers', 'Brussels', 'Belgium', None),
#  (57, 'Zeltweg', 'Styria', 'Austria', None),
#  (31, 'Donington Park', 'Castle Donington', 'UK', None),
#  (61, 'AVUS', 'Berlin', 'Germany', None),
#  (54, 'Le Mans', 'Le Mans', 'France', None),
#  (36, 'Autódromo Internacional Nelson Piquet', 'Rio de Janeiro', 'Brazil', None),
#  (30, 'Kyalami', 'Midrand', 'South Africa', None),
#  (45, 'Jarama', 'Madrid', 'Spain', None),
#  (49, 'Montjuïc', 'Barcelona', 'Spain', None),
#  (47, 'Scandinavian Raceway', 'Anderstorp', 'Sweden', None),
#  (28, 'Okayama International Circuit', 'Okayama', 'Japan', None),
#  (37, 'Detroit Street Circuit', 'Detroit', 'USA', None),
#  (63, 'Sebring International Raceway', 'Florida', 'USA', None),
#  (33, 'Phoenix street circuit', 'Phoenix', 'USA', None),
#  (67, 'Circuit de Pedralbes', 'Barcelona', 'Spain', None),
#  (52, 'Circuit Mont-Tremblant', 'Quebec', 'Canada', None),
#  (80, 'Las Vegas Strip Street Circuit', 'Las Vegas', 'United States', None),
#  (64, 'Ain Diab', 'Casablanca', 'Morocco', None),
#  (55, 'Reims-Gueux', 'Reims', 'France', None),
#  (51, 'Charade Circuit', 'Clermont-Ferrand', 'France', None),
#  (56, 'Prince George Circuit', 'Eastern Cape Province', 'South Africa', None),
#  (58, 'Aintree', 'Liverpool', 'UK', None),
#  (29, 'Adelaide Street Circuit', 'Adelaide', 'Australia', None),
#  (44, 'Las Vegas Street Circuit', 'Nevada', 'USA', None),
#  (62, 'Monsanto Park Circuit', 'Lisbon', 'Portugal', None),
#  (42, 'Fair Park', 'Dallas', 'USA', None),
#  (41, 'Dijon-Prenois', 'Dijon', 'France', None),
#  (40, 'Zolder', 'Heusden-Zolder', 'Belgium', None),
#  (46, 'Watkins Glen', 'New York State', 'USA', None),
#  (43, 'Long Beach', 'California', 'USA', None)]

# %% [markdown]
# ## 27. Who won the drivers championship when India hosted F1 for the first time?

# %%
# %%sql
# select concat(forename,' ',surname) as driver, c.location, c.country, c.name as circuit_name ,r.year
# from results re
# join drivers d on re.driverid = d.driverid
# join races r on re.raceid = r.raceid
# join circuits c on r.circuitid = c.circuitid
# where re.raceid = (select min(raceid) -- Subquery to get the raceid that Inida hosted F1 for the first time
# 				from races r
# 				join circuits c on r.circuitid = c.circuitid
# 				where country = 'India')
# and position = 1;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 1 rows affected.
# [('Sebastian Vettel', 'Uttar Pradesh', 'India', 'Buddh International Circuit', 2011)]

# %% [markdown]
# ## 28. Which driver has done the most lap time in F1 history?

# %%
# %%sql
# select driverid, driver, tot_time
# from(
# select l.driverid, concat(forename,' ',surname) as driver, sum(time) as tot_time,
# dense_rank() over(order by sum(time) desc) as rk
# from lap_times l
# join drivers d on l.driverid = d.driverid
# group by 1,2
# ) x -- Subquery to rank the total lap time in F1 history from highest to lowest.
# where rk = 1;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 1 rows affected.
# [(4, 'Fernando Alonso', datetime.timedelta(days=21, seconds=25024, microseconds=887000))]

# %% [markdown]
# ## 29. Name the top 3 drivers who have got the most podium finishes in F1 (Top 3 race finishes)

# %%
# %%sql
# select driver, no_podium
# from(
# 	select ds.driverid, concat(forename,' ',surname) as driver, count(1) as no_podium,
# 	dense_rank() over(order by count(1) desc) as rk
# 	from driver_standings ds
# 	join drivers d on ds.driverid = d.driverid
# 	where position in (1,2,3)
# 	group by 1,2
# 	order by 3 desc
# 	) x -- Subqueries to retrieve the number of podiums for each driver and rank them based on the number of podiums.
# where rk < 4;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 3 rows affected.
# [('Lewis Hamilton', 225),
#  ('Michael Schumacher', 203),
#  ('Sebastian Vettel', 145)]

# %% [markdown]
# ## 30. Which driver has the most pole position (no 1 in qualifying)

# %%
# %%sql
# select driverid, driver, no_pole
# from(
# 	select q.driverid, concat(forename,' ', surname) as driver, count(1) as no_pole,
# 	dense_rank() over(order by count(1) desc) as rk
# 	from qualifying q
# 	join drivers d on q.driverid = d.driverid
# 	where position = 1
# 	group by 1,2
# 	) x -- Subquery to rank the total number of pole from highest to lowest.
# where rk = 1;
# Out:
#  * postgresql://postgres:***@localhost/Case_Study
# 1 rows affected.
# [(1, 'Lewis Hamilton', 106)]

# %% [markdown]
# ## Reference:
# Link to kaggle dataset
# https://www.kaggle.com/datasets/rohanrao/formula-1-world-championship-1950-2020?resource=download
